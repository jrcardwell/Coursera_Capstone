# %% [markdown]
# <h1> Capstone Project - The Battle of the Neighborhoods (week 2)</h1>

# %% [markdown]
# # Dogs and Suds - Analysis of locations for a dog bar in Vancouver, BC, Canada.

# %% [markdown]
# ## Table of Contents
# * [Introduction](#introduction)
#     * [Background](#background)
#     * [Business Problem](#businessproblem)
#     * [Target Audience](#audience)
# * [Data](#data)

# %% [markdown]
# # Introduction <a name="introduction"></a>

# %% [markdown]
# ## Background<a name="background"></a>

# %% [markdown]
# The human relationship with "Man's best friend" goes back more than fifteen thousand years(1).  Archaeological discoveries from Greek and Roman Epitaphs suggest that even two thousand years ago, dogs were more than useful working animals, but a cherished part of the family(2). In Canada, there are almost 8 million dogs country-wide, and 35% of households have a dog(3,4). During COVID-19, Canada experienced a surge in pet ownership - 18% of pet owners reported obtaining a new pet since the start of the pandemic, with owners in the 18-24 age bracket most likely (38%) to have purchased a pet since then(4). COVID-19 has also been responsible for a majority of working Canadians to work from home, with this increased closeness causing the human-dog bond to be even stronger. As COVID-19 restrictions ease, there will be a need for 'outside' activities that do not jeopardize these bonds.
#
# Vancouver, located in British Columbia, Canada, is home to a growing number of craft breweries with more than 20 new breweries being added in the province each year since 2013, with 27 breweries in Vancouver alone as of 2020(5). This plethora of breweries supports an even larger number of pubs. Foursquare.com, a website that provides detailed information on more than 75 million venues worldwide, lists over 90 pubs within the city limits with many more in the surrounding suburbs.
#
# Off-leash beer gardens - dog bars - are a relatively new phenomenon, with a few in the United States
# (examples: [Paws For a Beer](https://www.pawsforabeer.com/?fbclid=IwAR1vR_nEbPuP_X_vJ_406pj7Hv4Frbwvf4XkB0jvN57R0N0PVcxLhbtSIMo) (Bellingham, WA),
# [Dog Bar St Pete](https://dogbarstpete.com/?fbclid=IwAR38NEeC8Zo49SXMmkkuhTP2CGJ0O72jJ_tAnsDC-MDUJAPf6Bekntcw9oU) (St. Petersberg, FL) and
# [Taps and Tails Dog Bar](https://www.tapsandtailsdogbar.com/)) (Cleveland, OH) and although there are a few dog-friendly pubs, there are no bona-fide dog bars in Vancouver. A dog bar is like an off-leash dog park with the addition of a full service bar so that owner and their dog can enjoy quality time socializing, meeting and getting to know new people (and dogs) and have a truly enjoyable outing together.  Opening a new dog bar will require detailed and well-thought out plan and involves many variables, not least of which is where in the city it would best be located.  In this project we will use demographic data combined with data from Foursquare.com to investigate the best neighborhood in which to create a dog bar in Vancouver.

# %% [markdown]
# ## Business Problem<a name="businessproblem"></a>

# %% [markdown]
# The problem this project aims to solve is to analyze which locations in the City of Vancouver would be the best in which to create a dog bar.    Using Machine-learning techniques such as Clustering analysis, the project will consider:
# <ul>
#     <li> which neighborhoods have existing dog parks?</li>
#     <li> which neighborhoods have existing pubs?</li>
#     <li> what is the density of dog-owning households in each neighborhood</li>
# </ul>

# %% [markdown]
# ## Target Audience<a name="audience"></a>

# %% [markdown]
# The key audience for this project will be entrepreneurs looking to open a novel business in an optimum location in Vancouver; armed with the insights gained in this project about where to locate it, they will be able to plan the next phase of their business plan to open Vancouver's first dog bar.  In addition, dog owners would benefit from knowing where their nearest dog parks would be, and, barring the introduction of an actual dog bar, if there is a pub on the way to or from the dog park that is dog-friendly.  Patrons of existing pubs would be interested in the outcome, particularly those with dogs.  Owners and potential owners of pubs as well as city planners would also benefit from insights into the locations of other pubs and the degree to which they are dog-friendly provided by this project.

# %% [markdown]
# # Data<a name="data"></a>

# %% [markdown]
# The sources of data for this project will be as follows.  For the purposes of this project, the 22 official neighborhoods of the City of Vancouver, also known as Local Plannning Areas, will be used.  We exclude data from neighboring cities that make up Greater Vancouver.  The University Endowment Lands are also excluded as they are under federal jurisdiction, and are not part of the City of Vancouver.  The sources of data are as follows:
#
# 1. Wikipedia.com
# <ul>
# <li>Description: list and descriptions of the 22 neighborhoods of the City of Vancouver, BC, Canada.</li>
# <li>Source: https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Vancouver</li>
# <li>Purpose: to identify the names and descriptions of the neighborhoods in Vancouver and, using the beautiful soup library, scrape the table from HTML into a Pandas Dataframe.</li>
# </ul>
# <br/>
#
# 2. City of Vancouver Open Data Portal
# <ul>
# <li>Description: listing of Vancouver's 22 neighborhoods including their names, bounding polygons and centroids</li>
# <li>Source: https://opendata.vancouver.ca/explore/dataset/local-area-boundary/table/</li>
# <li>Purpose: to identify the boundaries and central point of each neighborhood in Vancouver, BC</li>
# </ul>
# <br/>
#
#
# 3. People, Parks and Dogs Strategy Appendix
# <ul>
# <li>Description: PDF document containing a table containing Statistics Canada 2016 census data on dog-owning households in Vancouver Neighborhoods.</li>
# <li>Source: https://vancouver.ca/files/cov/people-parks-dogs-strategy-appendix.pdf <br/>
#     Note: since this is a pdf document and we did not cover this in the course, this required researching and using a different library to perform this type of scraping.  For this we used the tabula-py library. </li>
# <li>Purpose: to identify neighbourhoods with higher density of dog-owning households </li>
# </ul>
# <br/>
# 4. Foursquare API
# <ul>
# <li>Description: A web-based service that provides suggestions of places to visit (venues) near a user's location as well as tips and ratings from other users of those venues.  Foursquare also provides an API that can be used by developers to query the Foursquare data.</li>
# <li>Source: https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#     CLIENT_ID,
#     CLIENT_SECRET,
#     VERSION,
#     latitude,
#     longitude,
#     RADIUS,
#     LIMIT) where CLIENT_ID, CLIENT_SECRET, VERSION and LIMIT are static, developer and version-specific parameters, and the parameters latitude, longitude and radius cause the API to return venues within RADIUS meters of the geopoint at cooridnates specified by latitude and longitude.  The key data for this project will be the retuned venues for the center point of each neighborhood with categories 1) dog park/off-leash area and 2) pub, beer parlour, brew-pub or bar.  We will also investigate the user ratings of each.</li>
# <li>Purpose:to use the Foursquare API to identify, visualize and rank the distribution of pubs and existing dog parks across Vancouver neighborhoods.</li>
# </ul>
# <br/>

# %% [markdown]
# ## Methodology<a name="methodology"></a>

# %% [markdown]
# This analysis has the follow broad categories of steps.
# <ul>
#     <li> Prepare the environment.  This makes sure the necessary libraries are available for use in the subsequent steps</li>
#     <li> Retrieve and pre-process the data sets from the data sources described above.
#         <ol>
#             <li>Use Pandas to read a page from Wikipedia that contains the official names of the neighborhoods in Vancouver </li>
#             <li>Extract the list items using the BeautifulSoup library's 'findAll' method. </li>
#             <li>Use BeautifulSoup's 'find' method to extract the name from the list item by searching for the first anchor ("a href=..." element in the item. </li>
#             <li>Massage the data by removing redundant elements from the description column and editing any names that do not match the official name.</li>
#             <li>Create a Pandas DataFrame from the extracted data.</li>
#             <li>Extract the geo-coordinates of each neighborhood's centroid from the Open Data Portal (Data item 2 above).  This list is in JSON format, and the relevant fields are shortname, name, latitude and longitude.</li>
#             <li>Use Pandas 'merge' method to join the columns from the Open Data Portal DataFrame with the names DataFrame created from Wikipedia. </li>
#             <li>Use the geopandas, urllib and json libraries to download and read a json file containing the coordinates of the boundaries for each neighborhood. </li>
#             <li>Use the Tabula-py library to read a Portable Document Format (PDF) file from the Vancouver Parks Board containing a table of dog ownership by neighborhood in Vancouver.</li>
#             <li>Extract and rename the relevant columns Name, Area, LicensedDogs and DogDensity and confirm the data has 22 rows, dropping any irrelevant columns and rows.</li>
#             <li>Use the merge method again to merge the dog ownership DataFrame with the neighborhoods DataFrame.</li>
#             <li>Iterate through the new NeighborhoodsAndDogs DataFrame and make calls to the FourSquare API using the Search endpoint to find venues within 1.5 km of the geo-coordinates of the central point in each neighborhood whose category or name identifies it as a dog park.</li>
#             <li>Iterate through the NeighborhoodsAndDogs DataFrame and call the FourSquare API again using the Explore endpoint to search in the vicinity of each neighborhood's central point for venues categorized as: Gastropubs, Irish Pubs, Bars, Pubs or Breweries.</li>
#         </ol>
#     </li>
#     <li> Perform Exploratory Data Analysis to identify trends, outliers and areas of interest in the data.
#     	<ol>
# 		<li>Group the dog park data by neighborhood to produce counts of dog parks by neighborhoods.  The objective is to determine which neighborhoods are more or less well served by dog parks.</li>
# 		<li>Use Matplotlib library to plot the results in a bar chart showing the number of parks in each neighborhood in descending order.</li>
# 		<li>Use the Nominatim library to obtain the central coordinates for Vancouver, BC - this will be used later to produce Folium maps based on these coordinates.</li>
# 		<li>Create a Folium map of Vancouver using the Map method and add a title using the Map.Marker method. </li>
# 		<li>Add a circle at each neighborhood centroid with size equivalent to the 1.5km radius we used to call the FourSquare API data.  The intention is to verify that the radius used for the FourSquare calls maximized the chances of finding both dog parks and pubs and minimized the chances of missing key venues.</li>
# 		<li>Create a Bubble chart showing the number of dogs licensed in each neighborhood, with bubble size indicating the number of dogs. This should suggest areas well served by dog parks.</li>
# 		<li>Create a Bubble chart showing the density of dogs (licensed dogs / neighborhood area in hectares) for each neighborhood, with bubble size indicating the density. This accounts for the fact that some neighborhoods are much smaller than others.</li>
#
# 	</ol>
#     </li>
#     <li> Visualize the neighborhoods, dog parks and pubs data using Folium maps in order to get a better idea of where current dog parks and pubs are located.</li>
#     <li> Use an unsupervised machine learning technique to identify clusters in the pubs data to find locations
# with a higher number of pubs. For this analysis we will use k-means clustering, with the number of clusters ('k') being verified  using the 'elbow' method.</li>
#     <li> Finally, we will recommend a neighborhood in which to locate the dog bar based on neighborhoods identified with a high concentration of pubs that are currently poorly served by existing dog parks.</li>
# </ul>

# %% [markdown]
# ## Data Retrieval

# %% [markdown]
# ### 1. Preparation: Install and import the required libraries<a name="preparation">
#
# The primary tool in this analysis is Python and several Python libraries.  The first step is to install them to the local environment and import them into the notebook.

# %%
# bs4: the BeautifulSoup library used for scraping web site data
# !pip install bs4  

# geopy: the python geocoding library used for geo-locating an address
# !pip install geopy 

# folium: a mapping library used to render locations and venues on a map
# !pip install folium==0.5.0  

# tablua: a library used for scraping data from pdf documents
# !pip install tabula-py  

#geopandas: supports geographic data with Pandas objects
# !conda install geopandas
# Out:
# Requirement already satisfied: bs4 in c:\users\jcardwell\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jcardwell\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\jcardwell\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: geopy in c:\users\jcardwell\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\jcardwell\anaconda3\lib\site-packages (from geopy) (1.52)
# Requirement already satisfied: folium==0.5.0 in c:\users\jcardwell\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: six in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: branca in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jcardwell\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2021.5.30)
# Requirement already satisfied: tabula-py in c:\users\jcardwell\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\jcardwell\anaconda3\lib\site-packages (from tabula-py) (1.1.3)
# Requirement already satisfied: distro in c:\users\jcardwell\anaconda3\lib\site-packages (from tabula-py) (1.5.0)
# Requirement already satisfied: numpy in c:\users\jcardwell\anaconda3\lib\site-packages (from tabula-py) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\jcardwell\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jcardwell\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\jcardwell\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import pandas as pd
import numpy as np

from geopy import Nominatim

import geopandas as gdp
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# %matplotlib inline
from sklearn.cluster import KMeans
import folium

from bs4 import BeautifulSoup
import requests

from pandas.io.json import json_normalize

# ensure java is installed as it is a requirement for tabula
import tabula
import os

# all done importing    
print ('Libraries imported successfully')
# Out:
# Libraries imported successfully

# %%
# tablula requires java to be installed

java_home = os.environ.get('JAVA_HOME', None)

if not java_home:
    java_path = 'C:\\javajdk\\bin'
    os.environ['JAVA_HOME'] = java_path
    print(java_home)
else:
    print(java_home)
# Out:
# c:\javajdk\bin

# %% [markdown]
# ### 2. Wikipedia data
# Obtain a listing of the neighborhoods in Vancouver by scraping the wikipedia page listed in the first data source, massaging the data and storing it in a DataFrame.<br/>
# </li>
# </ul>

# %% [markdown]
# Use the BeautifulSoup library to extract the page from Wikipedia and then parse the page using python. The list is an unordered html list of which the page contains more than one.  First use BeautifulSoup's FindAll method to get all of the unordered lists, and then use a loop to determine which html "\<ul\>" tag contains "Arbutus-Greenway" and is therefore our target.

# %%
# build the URL
url='https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Vancouver'

# make a GET request to retrieve the page
wikidata = requests.get(url).text

# create a beautiful soup object containing the page data
soup = BeautifulSoup(wikidata,"html5lib")

# create an empty dictionary
neighborhoods = [] # initially empty list

#find un-ordered lists
ul_list = soup.findAll('ul')

ul_index = -1       # catch-all incase we don't find any <ul> tags
for index,ul in enumerate(ul_list):
    if('Arbutus_Greenway') in str(ul):
        ul_index = index
if (ul_index == -1):
    print("list not found")
else:
    print("the index of the neighborhood ul element is ", ul_index)
# Out:
# the index of the neighborhood ul element is  1

# %% [markdown]
# The unordered list we want is the one with index 1.  <br/>
# Each neighborhood is identified by an anchor tag "\<a href=...\>" within each list item ("\<li\>") and the description contains a repeat of the neighborhood name.  Parse the rows of the ul_list soup object to get the name and description and use python to strip out the redundant name.

# %%
#Get the desired unordered list row from the ResultSet at our index of interest.
li_list = ul_list[ul_index]

for li in li_list.findAll('li'):              # find the <li> tags
    cell = {}                                 # empty dictioinary
                                              # now loop inside the <li> item
    for link in li.find('a'):                 # find the first anchor tag (<a>)
        cell['Name'] = link.lstrip().rstrip() # assign the dictionary Name value and remove white space before and after the name
    
    basedesc = str(li.text)                   # get the text of the list item and strip out the duplicate name and hyphen
    strindex = basedesc.find('-')
    if (strindex > 0):
        strstart = strindex + 1 
    strend = len(basedesc) - strstart
                                               # assign the dictionary Description value and remove any leading white space
    cell['Description']=basedesc[strstart:strend].lstrip()
    
    neighborhoods.append(cell)                 # add the dictionary item to the neighborhoods list

# %% [markdown]
# Finally, create a Pandas DataFrame of the neighborhoods list.  One of the neighborhoods needs to be renamed to match its official name so that other datasets (below) can be merged with this one.

# %%
neighborhoodsdf = pd.DataFrame(neighborhoods)               # create a Pandas Datafram

neighborhoodsdf.replace("Arbutus Ridge",                    # clean up the name of this neighborhood to match its official name
           "Arbutus-Ridge",                    
           inplace=True)

print ("Neighborhoodsdf DataFrame created!")
# Out:
# Neighborhoodsdf DataFrame created!

# %% [markdown]
# Check on the shape to ensure we have all 22 neighborhoods

# %%
neighborhoodsdf.shape
# Out:
# (22, 2)

# %% [markdown]
# Check the first five rows to ensure they were extracted correctly.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #paste image here

# %% [markdown]
#  ### 3.  Open Data Portal data.
#  #### 3a. Get the geo-coordinates of each neighborhood from the Vancouver Open Data Portal.
#  The next step is to use Pandas to read and merge the Wikipedia Data Frame with the City of Vancouver Open Data Portal's JSON listing of the centroid of each neighborhood, again, wrangling the data so that only relevant columns are retained.
#
#  Because the data are in JSON format, use the Pandas library to parse the dataset.

# %%
# build the Open Data Portal url
odpurl='https://opendata.vancouver.ca/explore/dataset/local-area-boundary/download/?format=json&timezone=America/Los_Angeles&lang=en'

#issue a get request to obtain the data and parse it as a json document
odpdata = requests.get(odpurl).json()

# %% [markdown]
# The relevant parts of the JSON data are the id, name, fields.geom.coordinates (boundary polygon) and geo_point_2d which contains the latitude and longitude of the centroid of each neighborhood.

# %%
#get the population data (2016 Census) for each neighborhood also from the Open Data Portal, but in CSV format.  
#The data are from the 2016 Census and are made available under they are credited to
# Statistics Canada, Census 2016, custom order for City of Vancouver Local Areas' is acknowledged

#build the csv file name
popcsv='CensusLocalAreaProfiles2016Population.csv'
# use Pandas to read the pdf
popdf=pd.read_csv(popcsv)

# %%
popdf.columns=['ShortName','Name','Population']
# rename shortname for Killarney from 'KILL' to 'KIL' to match the other dataset
popdf['ShortName'][8]='KIL'
popdf
# Out:
# <ipython-input-1060-2d2a27d752f8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['ShortName'][8]='KIL'
#    ShortName                       Name  Population
# 0         AR             Arbutus-Ridge        15295
# 1        CBD                  Downtown        62030
# 2         DS         Dunbar-Southlands        21425
# 3       FAIR                  Fairview        33620
# 4         GW        Grandview-Woodland        29175
# 5         HS          Hastings-Sunrise        34575
# 6         KC  Kensington-Cedar Cottage        49325
# 7       KERR                Kerrisdale        13975
# 8        KIL                 Killarney        29325
# 9       KITS                 Kitsilano        43045
# 10      MARP                   Marpole        24460
# 11        MP            Mount Pleasant        32955
# 12       OAK                  Oakridge        13030
# 13        RC       Renfrew-Collingwood        51530
# 14        RP                Riley Park        22555
# 15      SHAU               Shaughnessy         8430
# 16        SC              South Cambie         7970
# 17       STR                Strathcona        12585
# 18       SUN                    Sunset        36500
# 19        VF        Victoria-Fraserview       31065
# 20        WE                  West End        47200
# 21       WPG           West Point Grey        13065

# %%
# namalize the json data into a new DataFrame
dfdtl =  json_normalize(odpdata)

# drop the non-key columns from the data frame
flds=dfdtl.drop(['datasetid','recordid','record_timestamp','fields.geom.type','geometry.type','geometry.coordinates'], axis=1)

# split the geo_point_2d into latitude and longitude
lat = []                                  # empty list of latitudes
lon = []                                  # empty list of longitudes
                                          
#iterate of the dataframe and get the lat and long values
for row in flds['fields.geo_point_2d']:
    lat.append(row[0])
    lon.append(row[1])
    
#join the lists onto the dataframe    
flds['latitude'] = lat
flds['longitude']= lon

#drop the geo_point_3d column now that we have separate lat/long columns
neighborhoods_geo = flds.drop(['fields.geo_point_2d','fields.geom.coordinates'],axis=1)

#rename the columns to friendlier and more descriptive values
neighborhoods_geo.columns=['ShortName','Name','Latitude','Longitude']

#rename the short name for Killarney from KILL to KIL to match the other dataset when we merge
neighborhoods_geo['ShortName']
#confirm we have 22 neighborhoods
neighborhoods_geo
# Out:
# <ipython-input-1061-379d4f08a661>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dfdtl =  json_normalize(odpdata)
#    ShortName                      Name   Latitude   Longitude
# 0         AR             Arbutus-Ridge  49.246805 -123.161669
# 1        CBD                  Downtown  49.280747 -123.116567
# 2       FAIR                  Fairview  49.264540 -123.131049
# 3         GW        Grandview-Woodland  49.276440 -123.066728
# 4         HS          Hastings-Sunrise  49.277934 -123.040270
# 5       MARP                   Marpole  49.210207 -123.128382
# 6         RP                Riley Park  49.244766 -123.103147
# 7       SHAU               Shaughnessy  49.245681 -123.139760
# 8        STR                Strathcona  49.278220 -123.088235
# 9         WE                  West End  49.285011 -123.135438
# 10        DS         Dunbar-Southlands  49.237962 -123.189547
# 11      KERR                Kerrisdale  49.223655 -123.159576
# 12       KIL                 Killarney  49.217022 -123.037647
# 13      KITS                 Kitsilano  49.267540 -123.163295
# 14        SC              South Cambie  49.245556 -123.121801
# 15        VF       Victoria-Fraserview  49.220012 -123.064135
# 16        KC  Kensington-Cedar Cottage  49.246686 -123.072885
# 17        MP            Mount Pleasant  49.263065 -123.098513
# 18       OAK                  Oakridge  49.226403 -123.123025
# 19        RC       Renfrew-Collingwood  49.247343 -123.040166
# 20       SUN                    Sunset  49.218756 -123.092038
# 21       WPG           West Point Grey  49.268401 -123.203467

# %% [markdown]
# #### Merge the neighborhoodsdf DataFrame with the OpenDataPortal DataFrame so that we have both descriptions and the geo-coordinates of each neighborhood

# %%
neighborhoodsFull1 = pd.merge(neighborhoods_geo, neighborhoodsdf, on='Name')
neighborhoodsFull = pd.merge(neighborhoodsFull1, popdf, on='ShortName')
neighborhoodsFull.drop(columns=['Name_y'],inplace=True)
neighborhoodsFull.rename(columns={'Name_x':'Name'}, inplace=True)
neighborhoodsFull
# Out:
#    ShortName                      Name   Latitude   Longitude  \
# 0         AR             Arbutus-Ridge  49.246805 -123.161669
# 1        CBD                  Downtown  49.280747 -123.116567
# 2       FAIR                  Fairview  49.264540 -123.131049
# 3         GW        Grandview-Woodland  49.276440 -123.066728
# 4         HS          Hastings-Sunrise  49.277934 -123.040270
# 5       MARP                   Marpole  49.210207 -123.128382
# 6         RP                Riley Park  49.244766 -123.103147
# 7       SHAU               Shaughnessy  49.245681 -123.139760
# 8        STR                Strathcona  49.278220 -123.088235
# 9         WE                  West End  49.285011 -123.135438
# 10        DS         Dunbar-Southlands  49.237962 -123.189547
# 11      KERR                Kerrisdale  49.223655 -123.159576
# 12       KIL                 Killarney  49.217022 -123.037647
# 13      KITS                 Kitsilano  49.267540 -123.163295
# 14        SC              South Cambie  49.245556 -123.121801
# 15        VF       Victoria-Fraserview  49.220012 -123.064135
# 16        KC  Kensington-Cedar Cottage  49.246686 -123.072885
# 17        MP            Mount Pleasant  49.263065 -123.098513
# 18       OAK                  Oakridge  49.226403 -123.123025
# 19        RC       Renfrew-Collingwood  49.247343 -123.040166
# 20       SUN                    Sunset  49.218756 -123.092038
# 21       WPG           West Point Grey  49.268401 -123.203467
#
#                                           Description  Population
# 0   Located in the middle of Vancouver's west side...       15295
# 1   The Central business district of Vancouver, co...       62030
# 2   Contains the popular attractions of Granville ...       33620
# 3   Woodland - A mature neighbourhood in east Vanc...       29175
# 4   Sunrise - One of Vancouver's oldest neighbourh...       34575
# 5   The neighbourhood contains a diverse range of ...       24460
# 6   Located in the centre of Vancouver and contain...       22555
# 7   An affluent and mostly residential neighbourho...        8430
# 8   One of the city's oldest neighbourhoods, conta...       12585
# 9   It is home to the city's historical gay commun...       47200
# 10  Southlands - An affluent neighbourhood on the ...       21425
# 11  A primarily residential neighbourhood bisected...       13975
# 12  Located in the southeastern corner of the city...       29325
# 13  Located along the south end of English Bay, th...       43045
# 14  One of Vancouver's smallest neighbourhoods, it...        7970
# 15  Fraserview - A multiculturally diverse neighbo...       31065
# 16  Cedar Cottage - One of the most multicultural ...       49325
# 17  Known for its unusual stores, heritage buildin...       32955
# 18  Known for being the location of Oakridge Mall,...       13030
# 19  Collingwood - A large, primarily residential n...       51530
# 20  An ethnically diverse, working-class neighbour...       36500
# 21  Grey is a mixed commercial and residential are...       13065

# %% [markdown]
# #paste image

# %% [markdown]
# #### 3b. Get the boundary points for each neighborhood from the City of Vancouver OpenData portal

# %%
#2b download the boundary points in a JSON datafile
import urllib.request
import json
url = https://opendata.vancouver.ca/explore/dataset/local-area-boundary/download/?format=geojson&timezone=America/Los_Angeles&lang=en'

filename = 'vancouvergeo.json'
urllib.request.urlretrieve(url, filename)
vancouvergeo = r'vancouvergeo.json'

#use geopandas to read the file
neighborhood_boundaries = gdp.read_file(vancouvergeo)
neighborhood_boundaries.columns=['ShortName','Name','Polygon']
neighborhood_boundaries.head()
# Out:
#   File "<ipython-input-1063-78b917151b63>", line 4
#     url = https://opendata.vancouver.ca/explore/dataset/local-area-boundary/download/?format=geojson&timezone=America/Los_Angeles&lang=en'
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 4. Get the population of dogs in each neighborhood from the Appendix to the Dogs, Parks and People Strategy  published by Vancouver Parks Board
# In order to attact dog owners, the new dog bar will ideally be located in a neighborhood in which a maxiumum number of households have dogs. We will use web scraping to extract data on dog licensing by neighborhood from the People, Parks and Dogs Strategy publihed by the Vancouver Parks board. We will superimpose this data on a Folium map of Vancouver's neighborhoods to visualize neighborhoods with higher numbers of licensed dogs. We assume that while dog licensing is less than 100%, the degree of compliance is the same across neighborhoods, so the proportion of actual dogs will be somewhat higher by about the same amount in each neighborhood.

# %% [markdown]
# The parks board data is in Portable Document format (PDF), which requires using another library (tablula) to scrape the table from the pdf.

# %%
# %%capture
#There are a lot of errors about missing java.io.images library, but since we don't need the images from the appendix,
# we can ignore them.  the capture directive above removes them from the output.

# Build the url to get the pdf document
fileurl='https://vancouver.ca/files/cov/people-parks-dogs-strategy-appendix.pdf'

# use tabula to read the pdf
tables=tabula.read_pdf(fileurl, pages = "all")

# %% [markdown]
# From the [actual document](https://vancouver.ca/files/cov/people-parks-dogs-strategy-appendix.pdf), we are interested in the first table of the appendix.  Create a new dataframe containing the relevant columns from that table.

# %%
tables[0]
# Out:
#                                         Neighbourhood  Area\r(ha)  \
# 0                                            West End       225.6
# 1                                            Downtown       467.4
# 2                                           Kitsilano       636.3
# 3                                      Mount Pleasant       372.1
# 4                                            Fairview       363.5
# 5                                  Grandview-Woodland       475.4
# 6                           Kensington-Cedar\rCottage       725.2
# 7                                          Riley Park       493.2
# 8                                        South Cambie       217.6
# 9                                    Hastings-Sunrise       833.2
# 10                                  Dunbar-Southlands       908.0
# 11                                          Killarney       693.4
# 12                                  West Point Grey 4       535.0
# 13                                Renfrew-Collingwood       810.0
# 14                                      Arbutus-Ridge       370.1
# 15                                Victoria-Fraserview       550.1
# 16                                             Sunset       657.6
# 17                                         Kerrisdale       660.9
# 18                                        Shaughnessy       448.0
# 19                                         Strathcona       437.0
# 20                                            Marpole       600.3
# 21                                           Oakridge       402.4
# 22  1 Number of license\r2 Area (hectares) of\r3 N...         NaN
#
#    Population\r(2011\rCensus) Licensed\rdogs\r(June\r2016)  Dog\rdensity1  \
# 0                      44,543                        1,563            6.9
# 1                      54,680                        3,037            6.5
# 2                      41,136                        2,888            4.5
# 3                      26,400                        1,663            4.5
# 4                      31,432                        1,522            4.2
# 5                      27,297                        1,657            3.5
# 6                      47,471                        1,862            2.6
# 7                      21,794                        1,171            2.4
# 8                       7,682                          476            2.2
# 9                      33,992                        1,548            1.9
# 10                     20,185                        1,568            1.7
# 11                     28,458                        1,184            1.7
# 12                     13,038                          904            1.7
# 13                     50,495                        1,333            1.6
# 14                     15,908                          598            1.6
# 15                     30,711                          818            1.5
# 16                     36,286                          870            1.3
# 17                     14,651                          817            1.2
# 18                      8,807                          540            1.2
# 19                     12,170                          523            1.2
# 20                     23,913                          650            1.1
# 21                     12,443                          363            0.9
# 22                        NaN                          NaN            NaN
#
#     Off-leash\rArea2\r(ha) Dog\rdensity\rrelative\rto OLA\rarea3
# 0                     0.31                                 5,004
# 1                     1.51                                 2,005
# 2                     1.27                                 2,268
# 3                     0.05                                30,468
# 4                     1.23                                 1,233
# 5                     0.00                                   N/A
# 6                     4.38                                   425
# 7                     2.31                                   508
# 8                     0.47                                 1,004
# 9                     4.04                                   383
# 10                    4.87                                   322
# 11                   22.28                                    53
# 12                    6.18                                   146
# 13                    4.74                                   281
# 14                    0.92                                   649
# 15                    1.98                                   414
# 16                    1.84                                   472
# 17                    7.10                                   115
# 18                    0.00                                   N/A
# 19                    2.79                                   187
# 20                    7.10                                    92
# 21                    0.00                                   N/A
# 22                     NaN                                   NaN

# %%
#get the first table
dogs_table=tables[0]

#clean up the data by dropping irrelevant columns
dogs_table.drop(['Population\r(2011\rCensus)','Off-leash\rArea2\r(ha)','Dog\rdensity\rrelative\rto OLA\rarea3'],inplace=True,axis=1)

#rename columns to simpolify mergin with the other datasets
dogs_table.columns=['Name','Area','LicensedDogs','DogDensity']

# %% [markdown]
# Check the output

# %%
dogs_table.head(5)
# Out:
#              Name   Area LicensedDogs  DogDensity
# 0        West End  225.6        1,563         6.9
# 1        Downtown  467.4        3,037         6.5
# 2       Kitsilano  636.3        2,888         4.5
# 3  Mount Pleasant  372.1        1,663         4.5
# 4        Fairview  363.5        1,522         4.2

# %% [markdown]
# Confirm that this DataFrame has 22 rows

# %%
dogs_table.shape
# Out:
# (23, 4)

# %%
#there is an extra row 
dogs_table
# Out:
#                                                  Name   Area LicensedDogs  \
# 0                                            West End  225.6        1,563
# 1                                            Downtown  467.4        3,037
# 2                                           Kitsilano  636.3        2,888
# 3                                      Mount Pleasant  372.1        1,663
# 4                                            Fairview  363.5        1,522
# 5                                  Grandview-Woodland  475.4        1,657
# 6                           Kensington-Cedar\rCottage  725.2        1,862
# 7                                          Riley Park  493.2        1,171
# 8                                        South Cambie  217.6          476
# 9                                    Hastings-Sunrise  833.2        1,548
# 10                                  Dunbar-Southlands  908.0        1,568
# 11                                          Killarney  693.4        1,184
# 12                                  West Point Grey 4  535.0          904
# 13                                Renfrew-Collingwood  810.0        1,333
# 14                                      Arbutus-Ridge  370.1          598
# 15                                Victoria-Fraserview  550.1          818
# 16                                             Sunset  657.6          870
# 17                                         Kerrisdale  660.9          817
# 18                                        Shaughnessy  448.0          540
# 19                                         Strathcona  437.0          523
# 20                                            Marpole  600.3          650
# 21                                           Oakridge  402.4          363
# 22  1 Number of license\r2 Area (hectares) of\r3 N...    NaN          NaN
#
#     DogDensity
# 0          6.9
# 1          6.5
# 2          4.5
# 3          4.5
# 4          4.2
# 5          3.5
# 6          2.6
# 7          2.4
# 8          2.2
# 9          1.9
# 10         1.7
# 11         1.7
# 12         1.7
# 13         1.6
# 14         1.6
# 15         1.5
# 16         1.3
# 17         1.2
# 18         1.2
# 19         1.2
# 20         1.1
# 21         0.9
# 22         NaN

# %% [markdown]
# There is an extra row and we notice that two of the names are slightly different from the previous list (extra "\r" in row 6 and extra " 4" on row 12; we will drop the extra row and update the names to match.

# %%
# delete the last row
dogs_table.drop([dogs_table.index[22]], inplace=True)
dogs_table.replace("West Point Grey 4",                    # clean up the name of this neighborhood to match its official name
           "West Point Grey",                    
           inplace=True)
dogs_table.replace("Kensington-Cedar\rCottage",                    # clean up the name of this neighborhood to match its official name
           "Kensington-Cedar Cottage",                    
           inplace=True)
dogs_table.head(5)
# Out:
#              Name   Area LicensedDogs  DogDensity
# 0        West End  225.6        1,563         6.9
# 1        Downtown  467.4        3,037         6.5
# 2       Kitsilano  636.3        2,888         4.5
# 3  Mount Pleasant  372.1        1,663         4.5
# 4        Fairview  363.5        1,522         4.2

# %% [markdown]
# Next we merge the dogs_table DataFrame with our neighborhoodsFull DataFrame on the column 'Name'

# %%
neighborhoodsAndDogs = pd.merge(neighborhoodsFull, dogs_table, on='Name')

#add a calculated column for the density of people
neighborhoodsAndDogs['HumanDensity']=neighborhoodsAndDogs['Population']/neighborhoodsAndDogs['Area']
neighborhoodsAndDogs.shape
# Out:
# (22, 10)

# %% [markdown]
# ### 5. FourSquare API data
# #### 5a. Use the FourSquare API to identify dog parks in the vicinity of each neighborhood.
# The new dog bar should be in a location with few or no existing dog parks, improving the chances that dog owners will patronize the new location. We will use the Foursquare API to identify dog parks in close proximity to the neighborhood centroids.  Then we will visualize these on a Folium map.

# %% [markdown]
# For security, the CLIENT_ID, CLIENT_SECRET and ACCESS_TOKEN are hidden in the cell below.

# %%
# @hidden_cell
CLIENT_ID = 'CAUY0NVNOIN1151A2UDU2JI4IFAGVOKOB1W0UFG5PVBDHIQR' # your Foursquare ID
CLIENT_SECRET = '2B3OHXWDMBGQBMDOWDFJWJW4CDTGRHJ0XVZ2YADOZ1S13OVJ2B3OHXWDMBGQBMDOWDFJWJW4CDTGRHJ0XVZ2YADOZ1S13OVJ' # your Foursquare Secret
ACCESS_TOKEN = 'XQJX5QJZRCZOA24OINDZWAHBCOTJJWPI3K3UTA0PCVYNU1YA' # your FourSquare Access Token

# %%
#define parameters for the Foursquare API call
#CLIENT_ID, CLIENT_SECRET and ACCESS_TOKEN were defined and then hidden the cell above this one
VERSION      = '20210616'
LIMIT        = 100
search_query = 'Dog Park'

# %% [markdown]
# Iterate through the neighborhoods and call the FourSquare API to identify venues within 1.5km of the latitude/longitude coordinates of the neighborhood's centroid where the venue name includes Dog Park.

# %%
# get dog parks within 1.5km of the neighborhood's centroid

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Create a function to get any existing Dog Parks in each neighborhood. The function will be called once for each neighorhood

# %%
# a function that returns the dog parks for all neighborhoods
def getNearbyDogParks(hoodnames, lats, lons, radius):
 

    search_query='Dog Park'
    parks_list=[]
    

    for hoodname,lat,lon in zip(hoodnames,lats,lons):
        parkurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID
                       , CLIENT_SECRET, lat, lon,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
    
# call the GET request 
        results = requests.get(parkurl).json()['response']['venues']  
    
        parks_list.append([(hoodname, 
                        lat, 
                        lon,
                        p['name'], 
                        get_category_type(p),
                        p['location']['lat'],
                        p['location']['lng'] ,
                        p['location']['distance']) for p in results])

    nearbyDogParks = pd.DataFrame([park for park_list in parks_list for park in park_list])
    nearbyDogParks.columns = ['Neighborhood',
                              'Neighborhood_Latitude',
                              'Neighborhood_longitude',
                              'DogPark',
                              'Category',
                              'DogPark_Latitude',
                              'DogPark_Longitude',
                              'DogPark_Distance']
    
    return nearbyDogParks

# %%
# get dog parks within 1.5km of the neighborhood's centroid
hoodnames = neighborhoodsAndDogs['Name']
lats = neighborhoodsAndDogs['Latitude']
lons = neighborhoodsAndDogs['Longitude']
radius = 1500
    
dogparks_raw = getNearbyDogParks(hoodnames,lats, lons, radius) 

#get those where either the name matches 'Dog Park' or the category matches 'Dog Run', and add them together into a dataframe
dfc1=dogparks_raw[dogparks_raw['DogPark'].str.contains('Dog Park')]
dfc2=dogparks_raw[dogparks_raw['Category'].str.contains('Dog Run', na=False)]
    
dogparks=pd.concat([dfc1, dfc2])
       
#remove duplicates where it matched both
dogparks=dogparks.drop_duplicates(subset=['DogPark'])

dogparks.shape
# Out:
# (29, 8)

# %%
dogparks.shape  #dogparks.loc[dogparks['Neighborhood']=='Downtown']
# Out:
# (29, 8)

# %% [markdown]
# Merge the boundary DataFrame with the neighborhoodsAndDogs DataFrame

# %%
neighborhoodsWithDogs_geo=pd.merge(neighborhoodsAndDogs,neighborhood_boundaries, on='ShortName')
neighborhoodsWithDogs_geo.drop(columns=['Name_y'], inplace=True)
neighborhoodsWithDogs_geo.rename(columns={'Name_x':'Name'}, inplace=True)
neighborhoodsWithDogs_geo['LicensedDogs'] = neighborhoodsWithDogs_geo['LicensedDogs'].replace({',': ''},regex=True).apply(pd.to_numeric,1)
 
neighborhoodsWithDogs_geo['DogparkAvailability'] = neighborhoodsWithDogs_geo['LicensedDogs']/neighborhoodsWithDogs_geo['Population']
neighborhoodsWithDogs_geo.shape
# Out:
# (22, 12)

# %% [markdown]
# #### 5b. Use the FourSquare API to identify pubs in Vancouver

# %% [markdown]
# We will use The following FourSquare venue categories to call the FourSquare API.  The values came from the list of categories on the FourSquare API reference: https://developer.foursquare.com/docs/build-with-foursquare/categories/
#
# gastropub: 4bf58dd8d48988d155941735
# irish pub: 52e81612bcbc57f1066b7a06
# bar:       4bf58dd8d48988d116941735
# pub:       4bf58dd8d48988d11b941735
# brewery:   50327c8591d4c4b30a586d5d

# %%
pub_categories='4bf58dd8d48988d155941735,52e81612bcbc57f1066b7a06,4bf58dd8d48988d116941735,4bf58dd8d48988d11b941735,50327c8591d4c4b30a586d5d'

# %%
# a function to extract the first category name from a categories list
def get_pub_type(categories): 
    return  [c['name'] for c in categories][0]

# %%
# a function that returns pubs near each neighborhood
def getNearbyPubs(hoodnames, lats, lons, radius):
    limit = 100
    version='20210616'
    pubs_list=[]


    for hoodname,lat,lon in zip(hoodnames,lats,lons):
    
        pubs_url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&oauth_token={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
                    CLIENT_ID, CLIENT_SECRET, ACCESS_TOKEN, version, lat, lon,pub_categories, radius, limit)
 
# call the GET request 
    
        try:
            pubresults = requests.get(pubs_url).json()['response']['groups'][0]['items']
            locals = [(hoodname,
                       lat,
                       lon,
                       item['venue']['id'],
                       item['venue']['name'],
                       get_pub_type(item['venue']['categories']),
                       item['venue']['location']['lat'], 
                       item['venue']['location']['lng'],
                       item['venue']['location'],
                       item['venue']['location']['distance']) for item in pubresults]    
       
          
            pubs_list.append(locals)


        except:
            locals = []

        nearbyPubs = pd.DataFrame([pub for pub_list in pubs_list for pub in pub_list])
        nearbyPubs.columns = ['Neighborhood',
                                  'Neighborhood_Latitude',
                                  'Neighborhood_longitude',
                                  'PubID',
                                  'PubName',
                                  'Categories',
                                  'Pub_Latitude',
                                  'Pub_Longitude',
                                  'Pub_location',
                                  'Pub_Distance']
        print(' .',end='')
    
    return nearbyPubs

# %%
pubsdf1 = getNearbyPubs(hoodnames,lats,lons,1500)
print('\nDone')
# Out:
#  . . . . . . . . . . . . . . . . . . . . . .
# Done

# %%
#filter the data for pubs only
pubtypes = ['Bar','Pub','Gastropub','Brewery','Irish Pub']
pubsdf = pubsdf1[pubsdf1['Categories'].isin(pubtypes)]
pubsdf.shape
# Out:
# (333, 10)

# %%
print('We have found {} pubs, bars, Irish pubs, gastropubs or breweries across the city of Vancouver.'.format(pubsdf.shape[0]))
# Out:
# We have found 333 pubs, bars, Irish pubs, gastropubs or breweries across the city of Vancouver.

# %%
pubsdf.head(5)
# Out:
#     Neighborhood  Neighborhood_Latitude  Neighborhood_longitude  \
# 0  Arbutus-Ridge              49.246805             -123.161669
# 1  Arbutus-Ridge              49.246805             -123.161669
# 2  Arbutus-Ridge              49.246805             -123.161669
# 3       Downtown              49.280747             -123.116567
# 4       Downtown              49.280747             -123.116567
#
#                       PubID                     PubName Categories  \
# 0  4b31753ef964a520450725e3         Cheshire Cheese Inn        Bar
# 1  4d374a7d7edba090ea6f239a          Rick's Bar & Grill  Gastropub
# 2  4edd40821081d87c69868b2a            Broadway Brewing    Brewery
# 3  5a0fd58f1b0ea50e677fd1a2              Dublin Calling        Pub
# 4  4aa6bc27f964a520df4a20e3  Steamworks Brewing Company    Brewery
#
#    Pub_Latitude  Pub_Longitude  \
# 0     49.235153    -123.155743
# 1     49.234528    -123.162169
# 2     49.259249    -123.166587
# 3     49.280245    -123.121308
# 4     49.285107    -123.111447
#
#                                         Pub_location  Pub_Distance
# 0  {'address': '5645 West Boulevard', 'crossStree...          1366
# 1  {'address': '2486 w 41st ave', 'crossStreet': ...          1367
# 2  {'address': '2-2801 W 16th Ave', 'lat': 49.259...          1430
# 3  {'lat': 49.28024548406235, 'lng': -123.1213076...           348
# 4  {'address': '375 Water St', 'crossStreet': 'at...           611

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# As a first step before performing clustering, perform exploratory data analysis to identify any outliers, trends or other observations about the data.

# %% [markdown]
# # First we explore the dog park data
# dogparks.describe()

# %% [markdown]
# There are 29 dog parks across the 22 neighborhoods with a median distance (as the crow flies) to a dog park of 1,865 meters. Some dog parks are up to 3.3 km away from the neighborhood centroid.
#
# Group the data by neighborhood

# %%
# group by DogPark count within neighborhoods and get the count in each (zeros will be dropped)
parks_grouped = dogparks.groupby("Neighborhood")["DogPark"].size().reset_index(name='counts') 
parks_grouped
# Out:
#                 Neighborhood  counts
# 0                   Downtown      11
# 1          Dunbar-Southlands       1
# 2                   Fairview       4
# 3           Hastings-Sunrise       1
# 4   Kensington-Cedar Cottage       2
# 5                  Kitsilano       1
# 6             Mount Pleasant       1
# 7        Renfrew-Collingwood       1
# 8                 Riley Park       1
# 9                Shaughnessy       2
# 10                Strathcona       1
# 11                  West End       2
# 12           West Point Grey       1

# %%
# Some of the neighborhood centroids are missing since they have no dog parks within a 1.5 km radius.  
# Create a DataFrame with zeros to handle these cases.
zeros = {'Neighborhood':neighborhoodsAndDogs['Name']}
zerodf = pd.DataFrame(zeros)
zerodf['zerocounts']=int(0)

#now group the parks to get the counts by neighborhood, then combine the grouped data with the zerodf Data Frame
parkcounts_by_neighborhood=pd.merge(zerodf,parks_grouped, on='Neighborhood', how='left')
parkcounts_by_neighborhood['ParkCount']=parkcounts_by_neighborhood['zerocounts']+parkcounts_by_neighborhood['counts'].fillna(0)
parkcounts_by_neighborhood.drop(columns=['zerocounts','counts'], inplace=True)
parkcounts_by_neighborhood.sort_values('ParkCount',ascending=False, inplace=True)
parkcounts_by_neighborhood
# Out:
#                 Neighborhood  ParkCount
# 1                   Downtown       11.0
# 2                   Fairview        4.0
# 16  Kensington-Cedar Cottage        2.0
# 7                Shaughnessy        2.0
# 9                   West End        2.0
# 21           West Point Grey        1.0
# 4           Hastings-Sunrise        1.0
# 19       Renfrew-Collingwood        1.0
# 6                 Riley Park        1.0
# 8                 Strathcona        1.0
# 10         Dunbar-Southlands        1.0
# 13                 Kitsilano        1.0
# 17            Mount Pleasant        1.0
# 20                    Sunset        0.0
# 18                  Oakridge        0.0
# 0              Arbutus-Ridge        0.0
# 15       Victoria-Fraserview        0.0
# 14              South Cambie        0.0
# 12                 Killarney        0.0
# 5                    Marpole        0.0
# 3         Grandview-Woodland        0.0
# 11                Kerrisdale        0.0

# %% [markdown]
# This indicates that of 22 neighborhoods, only 13 have a dog park within 1.5  km of the central point in the neighborhood.

# %%
#create a bar chart showing number of dog parks by neighborhood

parkcounts_by_neighborhood.index=parkcounts_by_neighborhood['Neighborhood']
parkcounts_by_neighborhood['ParkCount'].plot(kind='bar',figsize=(20,8), width=0.8)
plt.title('Number of Dog Parks by Neighborhood',fontsize=18)
plt.x=parkcounts_by_neighborhood['Neighborhood']
plt.y=parkcounts_by_neighborhood['ParkCount']
plt.xlabel('Neighborhood', fontsize=14)
plt.ylabel('Number of Dog Parks', fontsize=14)
# Out:
# Text(0, 0.5, 'Number of Dog Parks')

# %% [markdown]
# #### Visualize the neighborhoods by plotting their boundaries on a Folium map of Vancouver

# %%
#start with the central coordinates of the city using the Nominatim method of the geopy library
address = 'Vancouver, BC, Canada'

locator = Nominatim(user_agent="catuserbot")
location = locator.geocode(address)
latitude = location.latitude
longitude= location.longitude

vancouver_latlong = [latitude,longitude]
print ('The central geographic point of Vancouver, BC is {},{}.'.format(latitude,longitude))
# Out:
# The central geographic point of Vancouver, BC is 49.2608724,-123.1139529.

# %%
#calculate the area of a 1500 meter circle
from math import pi

r=1.5 # 1500m = 1.5km
area=round((pi * r**2) * 100,1) # (1 sq km = 100 hectares)
 
comment1='To determine whether the size of the area we used to generate the dog park data from the FourSquare API was appropriate, plot the neighborhood polygons on a Folium map, along with a circle of equivalent size based on 1.5km radius ({} hectares).'.format(area)
print(comment1)
# Out:
# To determine whether the size of the area we used to generate the dog park data from the FourSquare API was appropriate, plot the neighborhood polygons on a Folium map, along with a circle of equivalent size based on 1.5km radius (706.9 hectares).

# %%
from folium.features import DivIcon
vancouvermap = folium.Map(location=vancouver_latlong, zoom_start=12, tiles='CartoDB positron')

# add a title
title = '<h3 align="left" style="font-size: 20px">Map of Vancouver, BC Neighborhoods with 1.5km radius circles at their centroids.</h3></br/><h4>Inset titles are the neighborhood code and name</h4>'
titleloc = [49.33,-123.25]
folium.map.Marker(titleloc,
                  icon=DivIcon(icon_size=(500,36),
                               icon_anchor=(0,0),
                               html=title
                              )
                 ).add_to(vancouvermap)

# iterate over the neighborhoods and draw the neighborhood boundary on the map
for _,r in neighborhoodsWithDogs_geo.iterrows():
    lat     = r['Latitude']
    lon     = r['Longitude']
    name    = r['Name']
    shortname=r['ShortName']
    area    = r['Area']
    sim_geo = gdp.GeoSeries(r['Polygon']).simplify(tolerance=0.001)
    geo_j   = sim_geo.to_json()
    geo_j   = folium.GeoJson(data=geo_j, style_function=lambda x: {'fillColor': 'yellow'})
    geo_j.add_to(vancouvermap)
    
    # add the names and abbreviations as markers for each neighborhood     
    folium.Marker(location=[lat,lon],popup='Name {} <br/> Abbreviation: {}'.format(name,shortname), icon=folium.DivIcon(html=f"""<div style="font-family: arial; color: blue">{shortname}: {name}</div>""")).add_to(vancouvermap)
    
    # add a circle to mark the neighborhood centroid and make the marker the same size as the Foursquare search area
    folium.Circle(location=[lat,lon],
                  popup='{} <br> area={}'.format(name,area),
                  radius=1500, 
                  color='gray',
                  fill=True,
                  fill_color='gray'
                 ).add_to(vancouvermap)

    
# show the map                 
vancouvermap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_cf164e28a6df439b94854f493ca81b57%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cf164e28a6df439b94854f493ca81b57%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cf164e28a6df439b94854f493ca81b57%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_cf164e28a6df439b94854f493ca81b57%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B49.2608724%2C-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# The map indicates that the selected radius of 1600 Meters covers most of each neighborhood. <br/>
# Although there is some overlap, there are not large uncovered areas, which is the goal so that we maximize the number of   matches in the FourSquare data.
# <br/>Note that the University Endowment Lands to the west of West Point Grey and Dunbar-Southlands is not part of the city, and is excluded from this analysis.<br/>
# Now lets see how many dogs are in each neighborhood by plotting a Bubble Chart on the map using dogs per 1/5 of a hectare to determine the radius of the circle.

# %%
doglicensingmap = folium.Map(location=vancouver_latlong, zoom_start=12, tiles='CartoDB positron')

# Provide a title
title2 = '<h3 align="left" style="font-size: 20px">Bubble Chart showing the number of licensed dogs by neighborhood in Vancouver, BC'

folium.map.Marker(titleloc,
                  icon=DivIcon(icon_size=(500,36),
                               icon_anchor=(0,0),
                               html=title2
                              )
                 ).add_to(doglicensingmap)

# Iterate over the neighborhood dog licensing data and add a bubble to the map at each neighborhood
# Size the markers by the number of dogs licensed in the neighborhood

for _,r in neighborhoodsWithDogs_geo.iterrows():
    lat     = r['Latitude']
    lon     = r['Longitude']
    dogs    = r['LicensedDogs']
    name    = r['Name']
    shortname=r['ShortName']
    sim_geo = gdp.GeoSeries(r['Polygon']).simplify(tolerance=0.001)
    geo_j   = sim_geo.to_json()
    geo_j   = folium.GeoJson(data=geo_j, style_function=lambda x: {'fillColor': 'yellow'})
    geo_j.add_to(doglicensingmap)
    
    # add the abbreviations as markers for each neighborhood         
    folium.Marker(location=[lat,lon],popup=name,icon=folium.DivIcon(html=f"""<div style="font-family: arial; color: blue">{shortname}</div>""")).add_to(doglicensingmap)

    # add a Bubble sized according to the count of dogs licensed in each neighborhood
    folium.Circle(location=[lat,lon],
                  popup='{} <br/> Dogs Licensed: {} <br>  '.format(name, dogs),
                  radius=float(dogs)/2,    # scale the number for visibility by dividing the number by 2 
                  color='crimson',
                  fill=True,
                  fill_color='blue',
                  opacity=0.9
                 ).add_to(doglicensingmap)


# show the map                 
doglicensingmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_d9e14cbc72ef43e39ce157c07b1c4544%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d9e14cbc72ef43e39ce157c07b1c4544%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d9e14cbc72ef43e39ce157c07b1c4544%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_d9e14cbc72ef43e39ce157c07b1c4544%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B49.2608724%2C-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# The above chart indicates that Downtown, Kitsilano and Kensington-Cedar Cottage are neighborhoods with relatively high numbers of dogs.
# However, since the neighborhoods vary in size from 217.6 (South Cambie) to 833 (Hastings-Sunrise), lets view dog density (dogs per hectare) by neighborhood.

# %%
#create a bubble chart of dogs per hectare by neighborhood (density) 
dogdensitymap = folium.Map(location=vancouver_latlong, zoom_start=12, tiles='CartoDB positron')

# Provide a title
title3 = '<h3 align="left" style="font-size: 20px">Bubble Chart showing the density (number per Hectare) of licensed dogs by neighborhood in Vancouver, BC'
folium.map.Marker(titleloc,
                  icon=DivIcon(icon_size=(500,36),
                               icon_anchor=(0,0),
                               html=title3
                              )
                 ).add_to(dogdensitymap)

# iterate over the neighborhood dog data and display the boundaries
for _,r in neighborhoodsWithDogs_geo.iterrows():
    lat     = r['Latitude']
    lon     = r['Longitude']
    area    = r['Area']
    density = r['DogDensity']
    name    = r['Name']
    shortname=r['ShortName']
    sim_geo = gdp.GeoSeries(r['Polygon']).simplify(tolerance=0.001)
    geo_j   = sim_geo.to_json()
    geo_j   = folium.GeoJson(data=geo_j, style_function=lambda x: {'fillColor': 'yellow'})
    geo_j.add_to(dogdensitymap)
    
    # add the abbreviations as markers for each neighborhood     
    folium.Marker(location=[lat,lon],popup=name,icon=folium.DivIcon(html=f"""<div style="font-family: arial; color: blue">{shortname}</div>""")).add_to(dogdensitymap)

    # add a Bubble at the centroid of each neighborhood 
    # size the bubbles by the density (number of dogs / neighborhood area)
    folium.Circle(location=[lat,lon],
                  popup='{} <br/>  Area={} HA <br/> Density:{} '.format(name,  area, density),
                  radius=float(density)*200,    # scale the density to make the bubbles more visible 
                  color='green',
                  fill=True,
                  fill_color='lime green',
                  opacity=0.9
                 ).add_to(dogdensitymap)

 
#show the map                 
dogdensitymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_434ae2f6e318487d8a66cb182e09f860%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_434ae2f6e318487d8a66cb182e09f860%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_434ae2f6e318487d8a66cb182e09f860%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_434ae2f6e318487d8a66cb182e09f860%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B49.2608724%2C-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# The neighborhoods of West-End and Downtown followed by Kitsilano, Fairview and Mount Pleasant have relatively high density of dogs per hectare ranging from 6.9 to 4.2 dogs per hectare (median 4.5). Conversely, the southern neighborhoods have relatively low dog density with a median of 1.25 dogs / HA.

# %% [markdown]
# Next we'll plot the locations of dog parks.

# %%
dogparks.head(5)
# Out:
#    Neighborhood  Neighborhood_Latitude  Neighborhood_longitude  \
# 19     Downtown              49.280747             -123.116567
# 21     Downtown              49.280747             -123.116567
# 22     Downtown              49.280747             -123.116567
# 70     Fairview              49.264540             -123.131049
# 71     Fairview              49.264540             -123.131049
#
#                     DogPark Category  DogPark_Latitude  DogPark_Longitude  \
# 19  Emery Barnes (Dog Park)  Dog Run         49.277134        -123.123836
# 21      China Town Dog Park  Dog Run         49.278201        -123.104896
# 22                 Dog Park     Park         49.283052        -123.131714
# 70   Willow Street Dog Park     Park         49.264695        -123.120948
# 71        Tennyson Dog Park  Dog Run         49.263107        -123.144244
#
#     DogPark_Distance
# 19               663
# 21               893
# 22              1129
# 70               733
# 71               971

# %%
dogparkmap = folium.Map(location=vancouver_latlong, zoom_start=12, tiles='CartoDB positron')

# Provide a title
title3 = '<h3 align="left" style="font-size: 20px">Map of Vancouver showing the location of dog parks identified in the vicinity of the center of each neighborhood.'
folium.map.Marker(titleloc,
                  icon=DivIcon(icon_size=(500,36),
                               icon_anchor=(0,0),
                               html=title3
                              )
                 ).add_to(dogparkmap)

# iterate over the neighborhood dog data and add a bubble for each neighborhood
# size the bubbles by the density (number of dogs / neighborhood area)
for _,r in neighborhoodsWithDogs_geo.iterrows():
    lat     = r['Latitude']
    lon     = r['Longitude']
    name    = r['Name']
    sim_geo = gdp.GeoSeries(r['Polygon']).simplify(tolerance=0.001)
    geo_j   = sim_geo.to_json()
    geo_j   = folium.GeoJson(data=geo_j, style_function=lambda x: {'fillColor': 'yellow'})
    geo_j.add_to(dogparkmap)
    
# add the abbreviation for each neighborhood    
    folium.Marker(location=[lat,lon],popup=name,icon=folium.DivIcon(html=f"""<div style="font-family: arial; color: blue">{name}</div>""")).add_to(dogparkmap)

for _,p in dogparks.iterrows():
    lat     = p['DogPark_Latitude']
    lon     = p['DogPark_Longitude']
    dogpark = p['DogPark'].replace("'",'')
    nhood   = p['Neighborhood']
    distance= p['DogPark_Distance']

    
    folium.CircleMarker([lat,lon],
                  popup='Neighborhood:{}<br/>Dog Park: {}'.format(nhood,dogpark),
                  radius=5  ,  
                  color='blue',
                  fill=True,
                  fill_color='blue',
                  fill_opacity=1
                 ).add_to(dogparkmap)
    
dogparkmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_705fb79f103c4d0a9783d5719b38f250%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_705fb79f103c4d0a9783d5719b38f250%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_705fb79f103c4d0a9783d5719b38f250%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_705fb79f103c4d0a9783d5719b38f250%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B49.2608724%2C-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Now let's examine the pub data. Start by plotting the count of pubs per neighborhood

# %%
# group by pub count within neighborhoods 
pubs_grouped = pubsdf.groupby("Neighborhood")["PubName"].size().reset_index(name='counts') 
pubs_grouped.head()
# Out:
#          Neighborhood  counts
# 0       Arbutus-Ridge       3
# 1            Downtown      76
# 2   Dunbar-Southlands       2
# 3            Fairview      34
# 4  Grandview-Woodland      23

# %%
# again, some of the neighborhoods have zero pubs.  We need to handle those in order to display them
pubzeros = {'Neighborhood':pubsdf['Neighborhood']}
pubzerodf = pd.DataFrame(pubzeros)
pubzerodf['zerocounts']=int(0)

#now group the pubs to get the counts by neighborhood, then combine the grouped data with the pubzerodf Data Frame
pubcounts_by_neighborhood=pd.merge(zerodf,pubs_grouped, on='Neighborhood', how='left')
pubcounts_by_neighborhood['PubCount']=pubcounts_by_neighborhood['zerocounts']+pubcounts_by_neighborhood['counts'].fillna(0)
pubcounts_by_neighborhood.drop(columns=['zerocounts','counts'], inplace=True)
pubcounts_by_neighborhood.sort_values('PubCount',ascending=False, inplace=True)
pubcounts_by_neighborhood.shape
# Out:
# (22, 2)

# %%
#review the data
pubcounts_by_neighborhood.head()
# Out:
#       Neighborhood  PubCount
# 1         Downtown      76.0
# 9         West End      70.0
# 8       Strathcona      42.0
# 2         Fairview      34.0
# 17  Mount Pleasant      29.0

# %%
#create a bar chart showing number of pubs by neighborhood
pubcounts_by_neighborhood_indexed=pubcounts_by_neighborhood.index=pubcounts_by_neighborhood['Neighborhood']
pubcounts_by_neighborhood_indexed = pubcounts_by_neighborhood
#pubcounts_by_neighborhood_indexed

pubcounts_by_neighborhood_index['pubCount'].plot(kind='bar',figsize=(20,8), width=0.8)
plt.title('Number of Pubs by Neighborhood',fontsize=18)
plt.x=pubcounts_by_neighborhood_index['Neighborhood']
plt.y=pubcounts_by_neighborhood_index['pubCount']
plt.xlabel('Neighborhood', fontsize=14)
plt.ylabel('Number of Pubs', fontsize=14)
# Out:
# Text(0, 0.5, 'Number of Pubs')

# %%
# merge the parks and pubs groups DataFrames with the neighborhoodsWithDogs_geo DataFrame
parkcounts_by_neighborhood.reset_index(drop=True, inplace=True)
pubcounts_by_neighborhood.reset_index(drop=True, inplace=True)
groupcounts = pd.merge(parkcounts_by_neighborhood,pubcounts_by_neighborhood, on='Neighborhood')

dogsAndSuds=pd.merge(neighborhoodsWithDogs_geo,groupcounts, left_on='Name', right_on='Neighborhood')

# drop the redundant Neighborhood column
dogsAndSuds.drop(columns=['Neighborhood'], inplace=True)

dogsAndSuds['PubAvailability'] = dogsAndSuds['PubCount']/dogsAndSuds['Population']
dogsAndSuds['PubDensity'] = dogsAndSuds['PubCount']/dogsAndSuds['Area']
neighborhoodsWithDogs_geo.head()
# Out:
#   ShortName                Name   Latitude   Longitude  \
# 0        AR       Arbutus-Ridge  49.246805 -123.161669
# 1       CBD            Downtown  49.280747 -123.116567
# 2      FAIR            Fairview  49.264540 -123.131049
# 3        GW  Grandview-Woodland  49.276440 -123.066728
# 4        HS    Hastings-Sunrise  49.277934 -123.040270
#
#                                          Description  Population   Area  \
# 0  Located in the middle of Vancouver's west side...       15295  370.1
# 1  The Central business district of Vancouver, co...       62030  467.4
# 2  Contains the popular attractions of Granville ...       33620  363.5
# 3  Woodland - A mature neighbourhood in east Vanc...       29175  475.4
# 4  Sunrise - One of Vancouver's oldest neighbourh...       34575  833.2
#
#    LicensedDogs  DogDensity  HumanDensity  \
# 0           598         1.6     41.326668
# 1          3037         6.5    132.712880
# 2          1522         4.2     92.489684
# 3          1657         3.5     61.369373
# 4          1548         1.9     41.496639
#
#                                              Polygon  DogparkAvailability
# 0  POLYGON ((-123.15260 49.25723, -123.16488 49.2...             0.039098
# 1  POLYGON ((-123.11227 49.29016, -123.10424 49.2...             0.048960
# 2  POLYGON ((-123.14599 49.25712, -123.14540 49.2...             0.045271
# 3  POLYGON ((-123.07702 49.29025, -123.06778 49.2...             0.056795
# 4  POLYGON ((-123.05649 49.29349, -123.05190 49.2...             0.044772

# %%
def get_point_color(cat):
    if cat == 'Bar':
            return 'blue'
    elif cat == 'Pub': 
            return 'red'
    elif cat == 'Gastropub': 
            return 'orange'        
    elif cat == 'Irish Pub': 
            return 'green'
    elif cat == 'Brewery': 
            return 'gray'
    else:
        return 'red'

# %%
pubsmap = folium.Map(location=vancouver_latlong, zoom_start=12, tiles='CartoDB positron')

# Provide a title
title2 = '<h3 align="left" style="font-size: 20px">Map showing the location of pubs in Vancouver, BC.<br/><h4>Max 100 pubs per neighborhood.</h4><div style="font-size: 16px; font-weight:bolder"><span style="color:blue">Bar </span><span style="color:red">Pub </span><span style="color:green">Irish Pub </span><span style="color:gray">Brewery </span><span style="color:orange">Gastropub </span></div>'

folium.map.Marker(titleloc,
                  icon=DivIcon(icon_size=(600,36),
                               icon_anchor=(0,0),
                               html=title2
                              )
                 ).add_to(pubsmap)

# Iterate over the dogsAndSuds data and add a bubble to the map at each neighborhood
# Size the markers by the number of pubs in the neighborhood

for _,r in dogsAndSuds.iterrows():
    lat     = r['Latitude']
    lon     = r['Longitude']
    pubs    = r['PubCount']
    name    = r['Name']
    shortname=r['ShortName']
    sim_geo = gdp.GeoSeries(r['Polygon']).simplify(tolerance=0.001)
    geo_j   = sim_geo.to_json()
    geo_j   = folium.GeoJson(data=geo_j, style_function=lambda x: {'fillColor': 'yellow'})
    geo_j.add_to(pubsmap)
    
    # add the abbreviations as markers for each neighborhood         
    folium.Marker(location=[lat,lon],popup=name,icon=folium.DivIcon(html=f"""<div style="font-family: arial; color: blue">{shortname}</div>""")).add_to(pubsmap)

    # add a Bubble sized according to the count of dogs licensed in each neighborhood
for _,b in pubsdf.iterrows():

    lat     = b['Pub_Latitude']
    lon     = b['Pub_Longitude']
    nhood    = b['Neighborhood']
    name    = b['PubName']
    cat     = b['Categories']

    distance =b['Pub_Distance']
    folium.CircleMarker([lat,lon],
                  #popup='{}<br/>Pub: {} Distance: {}'.format(nhood,name,distance),
                  radius=3  ,  
                  color=get_point_color(cat),
                  fill=True,
                  fill_color=get_point_color(cat),
                  fill_opacity=1
                 ).add_to(pubsmap)
    # print(lat,lon)
# show the map                 
pubsmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_04157194f08a46b4b55268e1d46728e7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_04157194f08a46b4b55268e1d46728e7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_04157194f08a46b4b55268e1d46728e7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_04157194f08a46b4b55268e1d46728e7%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B49.2608724%2C-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Clustering Analysis
#
# There are several algorithms for use in cluster analysis - density-based clustering, hierarchical clustering, fuzzy clustering and k-means.  For this project, we will use the K-Means clustering algorithm, which is a  commonly used technique, is one of the simplest and works well with unlabelled data. With K-Means analysis, we will identify clusters of neighborhoods based on the number of pubs per person and the number of pubs per hectare. We will use the K-Means cluster analysis to find locations where the pubs are close together.

# %% [markdown]
# ### Preparation
# The K-Means clustering algorithm requires that the data are continuous (not categorical), so we will remove columns that are not continuous.  We will also use StandardScaler, a popular method for normalization of data that results in a mean and standard deviation of zero.

# %%
### get the data for training and normalize it using one-hot encoding
dogsAndSuds.shape
# Out:
# (22, 16)

# %%
print('The data contain {} unique categories of pubs.'.format(len(pubsdf['Categories'].unique())))
# Out:
# The data contain 5 unique categories of pubs.

# %% [markdown]
# ### Reduce complexity by removing unnecessary, categorical and redundant variables

# %%
dogsAndSuds
# Out:
#    ShortName                      Name   Latitude   Longitude  \
# 0         AR             Arbutus-Ridge  49.246805 -123.161669
# 1        CBD                  Downtown  49.280747 -123.116567
# 2       FAIR                  Fairview  49.264540 -123.131049
# 3         GW        Grandview-Woodland  49.276440 -123.066728
# 4         HS          Hastings-Sunrise  49.277934 -123.040270
# 5       MARP                   Marpole  49.210207 -123.128382
# 6         RP                Riley Park  49.244766 -123.103147
# 7       SHAU               Shaughnessy  49.245681 -123.139760
# 8        STR                Strathcona  49.278220 -123.088235
# 9         WE                  West End  49.285011 -123.135438
# 10        DS         Dunbar-Southlands  49.237962 -123.189547
# 11      KERR                Kerrisdale  49.223655 -123.159576
# 12       KIL                 Killarney  49.217022 -123.037647
# 13      KITS                 Kitsilano  49.267540 -123.163295
# 14        SC              South Cambie  49.245556 -123.121801
# 15        VF       Victoria-Fraserview  49.220012 -123.064135
# 16        KC  Kensington-Cedar Cottage  49.246686 -123.072885
# 17        MP            Mount Pleasant  49.263065 -123.098513
# 18       OAK                  Oakridge  49.226403 -123.123025
# 19        RC       Renfrew-Collingwood  49.247343 -123.040166
# 20       SUN                    Sunset  49.218756 -123.092038
# 21       WPG           West Point Grey  49.268401 -123.203467
#
#                                           Description  Population   Area  \
# 0   Located in the middle of Vancouver's west side...       15295  370.1
# 1   The Central business district of Vancouver, co...       62030  467.4
# 2   Contains the popular attractions of Granville ...       33620  363.5
# 3   Woodland - A mature neighbourhood in east Vanc...       29175  475.4
# 4   Sunrise - One of Vancouver's oldest neighbourh...       34575  833.2
# 5   The neighbourhood contains a diverse range of ...       24460  600.3
# 6   Located in the centre of Vancouver and contain...       22555  493.2
# 19  POLYGON ((-123.02356 49.23479, -123.02357 49.2...             0.025868
# 20  POLYGON ((-123.10696 49.20416, -123.10616 49.2...             0.023836
# 21  POLYGON ((-123.22445 49.27892, -123.20515 49.2...             0.069192
#
#     ParkCount  PubCount  PubAvailability  PubDensity
# 0         0.0       3.0         0.000196    0.008106
# 1        11.0      76.0         0.001225    0.162602
# 2         4.0      34.0         0.001011    0.093535
# 3         0.0      23.0         0.000788    0.048380
# 4         1.0       3.0         0.000087    0.003601
# 5         0.0       2.0         0.000082    0.003332
# 6         1.0       7.0         0.000310    0.014193
# 7         2.0       0.0         0.000000    0.000000
# 8         1.0      42.0         0.003337    0.096110
# 9         2.0      70.0         0.001483    0.310284
# 10        1.0       2.0         0.000093    0.002203
# 11        0.0       4.0         0.000286    0.006052
# 12        0.0       2.0         0.000068    0.002884
# 13        1.0      18.0         0.000418    0.028289
# 14        0.0       0.0         0.000000    0.000000
# 15        0.0       1.0         0.000032    0.001818
# 16        2.0       0.0         0.000000    0.000000
# 17        1.0      29.0         0.000880    0.077936
# 18        0.0       3.0         0.000230    0.007455
# 19        1.0       6.0         0.000116    0.007407
# 20        0.0       3.0         0.000082    0.004562
# 21        1.0       5.0         0.000383    0.009346

# %%
kmdata = dogsAndSuds.drop(columns=['ShortName','Description','Polygon', 'Area','Population','Latitude','Longitude'])
kmdata = pubsdf.drop(columns=['Neighborhood','Neighborhood_Latitude','Neighborhood_longitude','PubID','PubName','Pub_location','Pub_Distance','Categories'])
kmdata.shape
# Out:
# (333, 2)

# %% [markdown]
# leave Name there for the moment - we will remove it before the clustering analysis step.
# Columns: LicensedDogs, DogDensity, HumanDensity,DogparkAvailability,ParkCount, PubCount,PubAvailability,PubDensity

# %% [markdown]
# ### Normalize the data using the StandardScaler method

# %% [markdown]
# The k-Means algorithm along with many other Machine Learning algorithms requires that all data are continuous variables and that the data have been normalized, and it is obvious from the data that some of the columns have drastically different scale form others. To mitigate against this we will use the StandardScaler which is a common normalization method and leaves the data with zero mean and standard deviation.

# %%
from sklearn.preprocessing import StandardScaler
X = kmdata.values[:,:] #[:,1]
kmdata_norm = StandardScaler().fit_transform(X)
kmdata_norm
# Out:
# array([[-2.44917139e+00, -1.48699444e+00],
#        [-2.49011837e+00, -1.71773151e+00],
#        [-8.72252913e-01, -1.87640217e+00],
#        [ 5.01869289e-01, -2.50403845e-01],
#        [ 8.20023732e-01,  1.03682701e-01],
#        [ 1.80901798e-01, -2.34196424e-01],
#        [ 4.62898000e-01, -3.02198595e-01],
#        [ 4.51314399e-01, -3.00952322e-01],
#        [ 1.12285785e+00, -9.79850816e-02],
#        [ 4.99760104e-01,  1.63469099e-01],
#        [ 6.96098899e-01,  3.61236668e-01],
#        [ 4.28026315e-01, -3.07637090e-01],
#        [ 7.50396414e-01,  1.16878600e-02],
#        [ 7.01908997e-01,  1.90296214e-01],
#        [ 7.39093468e-01,  1.74133600e-02],
#        [ 2.64135321e-01,  5.12042391e-01],
#        [ 6.39244908e-01, -7.23469487e-01],
#        [-5.91331139e-01, -2.56122780e+00],
#        [-2.56562630e-01, -2.54753359e+00],
#        [-5.78954186e-01, -3.35538678e+00]])

# %% [markdown]
# ### Determine the optimum value of K

# %% [markdown]
# To determine how many clusters (K), it is common to run the k-means algorithm several times and evaluate the impact of changing 'k' on the within cluster sum of squares (squared Euclidean distance from the value to the mean), also called inertia, each time.
# We will use the 'Elbow' method for this evaluation.

# %%
# create a list of sum of squared errors (distance from the mean**2)
sse = []

Krange = range(1,15)
for k in Krange:
    #train the model with the current value of k
    kmeans = KMeans(n_clusters = k)
    kmeans = kmeans.fit(kmdata_norm)
    
    #save the resultant sum of squares error
    sse.append(kmeans.inertia_)
sse
# Out:
# [665.9999999999999,
#  426.69105998295197,
#  291.58594717900274,
#  198.22218598339836,
#  159.82506214692043,
#  117.58849609415304,
#  96.40095218145228,
#  84.27545311059906,
#  73.14081773862432,
#  64.14998310217615,
#  53.69310764852882,
#  47.74195976760601,
#  43.79886065294887,
#  38.87907203089182]

# %% [markdown]
# ### Plot Inertia by the number of clusters requested

# %%
plt.plot(Krange, sse, 'bx-')
plt.title('Evaluation of the number of clusters on Inertia (Elbow method)')
plt.xlabel('# of clusters (k)')
plt.ylabel('Inertia')

plt.show()

# %% [markdown]
# ### The inflection point (the elbow) at 6 clusters suggests that this is the optimal value for K.

# %%
kOpt=6
#train the model
k_means = KMeans(init = "k-means++", n_clusters = kOpt, n_init = 10)
k_means.fit(kmdata_norm)
clusternum = k_means.labels_
kmdata['Group'] = clusternum+1
kmdata
# Out:
#      Pub_Latitude  Pub_Longitude  Group
# 0       49.235153    -123.155743      1
# 1       49.234528    -123.162169      1
# 2       49.259249    -123.166587      6
# 3       49.280245    -123.121308      2
# 4       49.285107    -123.111447      2
# ..            ...            ...    ...
# 437     49.275714    -123.201527      6
# 438     49.264401    -123.184286      6
# 439     49.263541    -123.185658      6
# 440     49.268657    -123.185277      6
# 441     49.263730    -123.207773      6
#
# [333 rows x 3 columns]

# %% [markdown]
# ### Plot the clusters

# %%
figure(num=None, figsize=(12, 9), dpi=80, facecolor='w', edgecolor='k')
plt.scatter(kmdata.iloc[:, 1], kmdata.iloc[:, 0], c=kmdata.iloc[:,2], s=100, cmap='rainbow')
centers = kmeans.cluster_centers_

plt.show()
#plt.xlim(min(kmdata.iloc[:,0]) -10, -50
#        )
#plt.scatter(
#centers[:, 0],
#centers[:, 1],
#c='black',
#s=200,
#alpha=0.3);

# %%
def get_cluster_color(c):
    if   c == 1:
            return 'blue'
    elif c == 2: 
            return 'violet'
    elif c == 3: 
            return 'antiquewhite'        
    elif c == 4: 
            return 'yellow'
    elif c == 5: 
            return 'darkorange'
    elif c == 6: 
            return 'red'        
    else:
        return 'blue'

# %%
pubsmap = folium.Map(location=vancouver_latlong, zoom_start=12, tiles='CartoDB positron')

# Provide a title
title2 = '<h3 align="left" style="font-size: 20px">Map showing the location of pub clusters in Vancouver, BC.<br/> \
<h4>Max 100 pubs per neighborhood.</h4> \
<div style="font-size: 16px; font-weight:bolder"> \
<span style="color:blue">CLuster 1 </span> \
<span style="color:violet">CLuster 2 </span> \
<span style="color:antiquewhite">CLuster 3 </span> \
<span style="color:yellow">CLuster 4 </span> \
<span style="color:darkorange">CLuster 5 </span> \
<span style="color:red">CLuster 6 </span></div>'

folium.map.Marker(titleloc,
                  icon=DivIcon(icon_size=(600,36),
                               icon_anchor=(0,0),
                               html=title2
                              )
                 ).add_to(pubsmap)

# Iterate over the dogsAndSuds data and add a bubble to the map at each neighborhood
# Size the markers by the number of pubs in the neighborhood

for _,r in dogsAndSuds.iterrows():
    lat     = r['Latitude']
    lon     = r['Longitude']
    pubs    = r['PubCount']
    name    = r['Name']
    shortname=r['ShortName']
    sim_geo = gdp.GeoSeries(r['Polygon']).simplify(tolerance=0.001)
    geo_j   = sim_geo.to_json()
    geo_j   = folium.GeoJson(data=geo_j, style_function=lambda x: {'fillColor': None})
    geo_j.add_to(pubsmap)
    
    # add the abbreviations as markers for each neighborhood         
    folium.Marker(location=[lat,lon],popup=name,icon=folium.DivIcon(html=f"""<div style="font-family: arial; color: blue">{name}</div>""")).add_to(pubsmap)

    # add a Bubble sized according to the count of dogs licensed in each neighborhood
for _,b in kmdata.iterrows():

    lat         = b['Pub_Latitude']
    lon         = b['Pub_Longitude']
    cluster     = b['Group']


    folium.CircleMarker([lat,lon],
                  #popup='{}<br/>Pub: {} Distance: {}'.format(nhood,name,distance),
                  radius=4  ,  
                  color=get_cluster_color(cluster),
                  fill=True,
                  fill_color=get_cluster_color(cluster),
                  fill_opacity=1
                 ).add_to(pubsmap)
    # print(lat,lon)
# show the map                 
pubsmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_9ed72f27e5f8420bb5860ad23f4cc180%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9ed72f27e5f8420bb5860ad23f4cc180%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_9ed72f27e5f8420bb5860ad23f4cc180%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_9ed72f27e5f8420bb5860ad23f4cc180%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B49.2608724%2C-123.1139529%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20% ...

# %%
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, title, sort_colors=True, emptycols=0):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12
    topmargin = 40

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(color))),
                         name)
                        for name, color in colors.items())
        names = [name for hsv, name in by_hsv]
    else:
        names = list(colors)

    n = len(names)
    ncols = 4 - emptycols
    nrows = n // ncols + int(n % ncols > 0)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + margin + topmargin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-topmargin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()
    ax.set_title(title, fontsize=24, loc="left", pad=10)

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

plot_colortable(mcolors.BASE_COLORS, "Base Colors",
                sort_colors=False, emptycols=1)
plot_colortable(mcolors.TABLEAU_COLORS, "Tableau Palette",
                sort_colors=False, emptycols=2)

plot_colortable(mcolors.CSS4_COLORS, "CSS Colors")

# Optionally plot the XKCD colors (Caution: will produce large figure)
# xkcd_fig = plot_colortable(mcolors.XKCD_COLORS, "XKCD Colors")
# xkcd_fig.savefig("XKCD_Colors.png")

plt.show()

# %%
print(vancouvergeo.json)
vancouvermap.choropleth(geo_data=filename,data=filename,key_on='features.feature',fill_color='Y1OrRd',fill_opacity=0.7,line_opacity=0.2,legend_name='Vancouver Neighborhoods',highlight=True)
vancouvermap
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-225-f41c25d30bb7> in <module>
# ----> 1 print(vancouvergeo.json)
#       2 vancouvermap.choropleth(geo_data=filename,data=filename,key_on='features.feature',fill_color='Y1OrRd',fill_opacity=0.7,line_opacity=0.2,legend_name='Vancouver Neighborhoods',highlight=True)
#       3 vancouvermap
#
# AttributeError: 'str' object has no attribute 'json'

# %%
#park_list = []
#for hoodname, lat, lon in zip(neighborhoodsAndDogs['Name'],neighborhoodsAndDogs['Latitude'],neighborhoodsAndDogs['Longitude']) :
#    parks = getNearbyDogParks(hoodname,lat,lon,LIMIT)
#    park_list.append(parks)
#    #print (' .', end='')
#   #print('Completed')
#    print (park_list.loc['neighborhood'])
#park_list
park_list = getNearbyDogParks(neighborhoodsAndDogs['Name'],
                              neighborhoodsAndDogs['Latitude'],
                              neighborhoodsAndDogs['Longitude'])

park_listdf=pd.DataFrame(park_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-43010c590709> in <module>
#       7 #    print (park_list.loc['neighborhood'])
#       8 #park_list
# ----> 9 park_list = getNearbyDogParks(neighborhoodsAndDogs['Name'],
#      10                               neighborhoodsAndDogs['Latitude'],
#      11                               neighborhoodsAndDogs['Longitude'])
#
# TypeError: getNearbyDogParks() missing 1 required positional argument: 'radius'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 5.  Use the FourSquare API to identify pubs in the vicinity of each neighborhood.
# Finally, the new dog bar would ideally be located in neighborhoods with existing pubs - this strategy takes advantage of the fact that existing pub owners have already determined that the demographics, availability of transportation, parking and other attributes are likely to attract pub-going patrons and have used advertising and promotion to attract customers. With the addition of a dog bar, dog-owning pub customers in these neighborhoods would now have a new attractive choice of venue.  To determine the best location, this project will use the Foursquare API data, apply clustering analysis (such as K-Means clustering) and/or correlation to find and visualize neighborhoods with high numbers of existing pubs, particularly those with high dog-friendliness scores in the FourSquare data and that also correspond to neighborhoods with few or no dog parks but with high levels of dog ownership.
#     <br/>
#     Here is an example of the data for pubs in the vicinity of the same neighborhood as the dog park data (Arbutus-Ridge):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### References:

# %% [markdown]
# <ol>
# <li>
# Serpell, J. (1995). The Domestic Dog: Its Evolution, Behaviour and Interactions with People. Retrieved from https://books.google.com.au/books?id=I8HU_3ycrrEC&lpg=PA7&dq=Origins%20of%20the%20dog%3A%20domestication%20and%20early%20history%20%2F%E2%80%8B%20Juliet%20Clutton-Brock&pg=PA7#v=onepage&q&f=false
#     </li>
#     <li>
# Podberscek,Anthony L.,  Paul, Elizabeth S. and Serpell, James A.(2005) Companion Animals and Us: Exploring the Relationship Between People and Pets. Cabridge University Press
#     </li>
#     <li>
# Bush (2011). Canada's Pet Wellness Report. Retrieved from:  https://www.canadianveterinarians.net/documents/canada-s-pet-wellness-report2011#:~:text=The%20subject%20of%20pet%20wellness,(source%3A%20Ipsos%20Reid).
#     </li>
#     <li>
# Chapman, M and Pisani, S. (2020) https://narrativeResearch.ca/canada-has-seen-a-significant-increase-in-pet-owners-since-the-start-of-the-covid-19-pandemic/
#     </li>
#     <li>
#         Siren, C (2021) https://www.cahi-icsa.ca/news/2020-canadian-pet-population-figures-released
#     </li>
#     <li>
#       Wiebe, J, 2020. Looking Back on the Biggest Decade in BC Craft Beer History  https://bcaletrail.ca/looking-back-on-the-biggest-decade-in-bc-craft-beer-history/
#     </li>
# </ol>
