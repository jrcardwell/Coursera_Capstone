# %% [markdown]
# # Preparation: Install and import the required libraries

# %%
# !pip install bs4
# !pip install geopy
# !pip install folium==0.5.0
# Out:
# Requirement already satisfied: bs4 in c:\users\jcardwell\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jcardwell\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\jcardwell\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: geopy in c:\users\jcardwell\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\jcardwell\anaconda3\lib\site-packages (from geopy) (1.52)
# Requirement already satisfied: folium==0.5.0 in c:\users\jcardwell\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: requests in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: jinja2 in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: branca in c:\users\jcardwell\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jcardwell\anaconda3\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jcardwell\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)

# %%
from geopy import Nominatim
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
import folium
print ('Libraries imported successfully')
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %% [markdown]
# # 1. Get the Wikipedia page for Vancouver Neighborhoods

# %%
url='https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Vancouver'

# %%
wikidata = requests.get(url).text

# %% [markdown]
# create a beautiful soup object

# %%
soup = BeautifulSoup(wikidata,"html5lib")

# %%
neighborhoods = [] # empty dictionary

ul_list = soup.findAll('ul')
ul_index = -1
for index,ul in enumerate(ul_list):
    if('Arbutus_Greenway') in str(ul):
        ul_index = index
if (ul_index == -1):
    print("list not found")
else:
    print("the index of the neighborhood ul element is ", ul_index)
# Out:
# the index of the neighborhood ul element is  1

# %% [markdown]
# Data Cleansing. The table contains an unordered list, with each neighborhood identified by a href object within a list item and the descriptions contain a repeat of the neighborhood name.  Parse the soup object to get the name and descript. Use python to strip out the redundant name.

# %%
 
rows = ul_list[ul_index]

for li in rows.findAll('li'):
    cell = {}
    
    for link in li.find('a'):
        cell['Name'] = link.lstrip().rstrip()
    
    basedesc = str(li.text)
    strindex = basedesc.find('-')
    if (strindex > 0):
        strstart = strindex + 1
    
    strend = len(basedesc) - strstart
    cell['Description']= basedesc[strstart:strend].lstrip()
    neighborhoods.append(cell)
       

df = pd.DataFrame(neighborhoods)
df.replace("Arbutus Ridge", 
           "Arbutus-Ridge", 
           inplace=True)

# %%
df.head()
# Out:
#                  Name                                        Description
# 0       Arbutus-Ridge  Located in the middle of Vancouver's west side...
# 1            Downtown  The Central business district of Vancouver, co...
# 2   Dunbar-Southlands  Southlands - An affluent neighbourhood on the ...
# 3            Fairview  Contains the popular attractions of Granville ...
# 4  Grandview-Woodland  Woodland - A mature neighbourhood in east Vanc...

# %% [markdown]
# Confirm the shape of the list of neighborhoods to make sure we got all 22.

# %%
df.shape
# Out:
# (22, 2)

# %% [markdown]
# # 2. Get the Geo-coordinates of Vancouver Neighborhoods

# %% [markdown]
# Again using BeautifulSoup to scrape the data, get the associated latitude and longitude of each neighborhood from the City of Vancouver Open Data Portal.

# %%
odpurl='https://opendata.vancouver.ca/explore/dataset/local-area-boundary/download/?format=json&timezone=America/Los_Angeles&lang=en'
odpdata = requests.get(odpurl).json()

# %% [markdown]
# The relevant parts of the JSON are the id, name and geo_point_2d, which contains the lat/long coordinates.

# %%
dfdtl = json_normalize(odpdata)
dfdtl
# Out:
# <ipython-input-67-ae5f293e470f>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   
# 6   [-123.103146806, 49.2447664796]
# 7   [-123.139760167, 49.2456809771]
# 8   [-123.088235281, 49.2782195786]
# 9   [-123.135437653, 49.2850111894]
# 10  [-123.189546803, 49.2379619063]
# 11  [-123.159576182, 49.2236554855]
# 12  [-123.037647029, 49.2170216717]
# 13   [-123.16329474, 49.2675398494]
# 14  [-123.121800916, 49.2455564633]
# 15   [-123.064134718, 49.220011941]
# 16  [-123.072884592, 49.2466864472]
# 17   [-123.09851312, 49.2630652507]
# 18  [-123.123024604, 49.2264031973]
# 19  [-123.040166465, 49.2473427346]
# 20  [-123.092038001, 49.2187561515]
# 21  [-123.203467483, 49.2684012111]

# %% [markdown]
# key colunms are fields.mapid, fields.name, fields.geometry_coordinates - we will drop the rest

# %%
flds=dfdtl.drop(['datasetid','recordid','record_timestamp','fields.geom.type','fields.geom.coordinates','geometry.type','geometry.coordinates'], axis=1)

flds
# Out:
#    fields.mapid               fields.name              fields.geo_point_2d
# 0            AR             Arbutus-Ridge  [49.2468049108, -123.161669238]
# 1           CBD                  Downtown  [49.2807470711, -123.116567008]
# 2          FAIR                  Fairview  [49.2645404871, -123.131048865]
# 3            GW        Grandview-Woodland  [49.2764396102, -123.066728221]
# 4            HS          Hastings-Sunrise   [49.277934053, -123.040269923]
# 5          MARP                   Marpole   [49.2102074666, -123.12838166]
# 6            RP                Riley Park  [49.2447664796, -123.103146806]
# 7          SHAU               Shaughnessy  [49.2456809771, -123.139760167]
# 8           STR                Strathcona  [49.2782195786, -123.088235281]
# 9            WE                  West End  [49.2850111894, -123.135437653]
# 10           DS         Dunbar-Southlands  [49.2379619063, -123.189546803]
# 11         KERR                Kerrisdale  [49.2236554855, -123.159576182]
# 12          KIL                 Killarney  [49.2170216717, -123.037647029]
# 13         KITS                 Kitsilano   [49.2675398494, -123.16329474]
# 14           SC              South Cambie  [49.2455564633, -123.121800916]
# 15           VF       Victoria-Fraserview   [49.220011941, -123.064134718]
# 16           KC  Kensington-Cedar Cottage  [49.2466864472, -123.072884592]
# 17           MP            Mount Pleasant   [49.2630652507, -123.09851312]
# 18          OAK                  Oakridge  [49.2264031973, -123.123024604]
# 19           RC       Renfrew-Collingwood  [49.2473427346, -123.040166465]
# 20          SUN                    Sunset  [49.2187561515, -123.092038001]
# 21          WPG           West Point Grey  [49.2684012111, -123.203467483]

# %% [markdown]
# split the lat/long into separate columns

# %%
lat = []
lon = []

for row in flds['fields.geo_point_2d']:
    lat.append(row[0])
    lon.append(row[1])
flds['latitude'] = lat
flds['longitude']= lon

flds
# Out:
#    fields.mapid               fields.name              fields.geo_point_2d  \
# 0            AR             Arbutus-Ridge  [49.2468049108, -123.161669238]
# 1           CBD                  Downtown  [49.2807470711, -123.116567008]
# 2          FAIR                  Fairview  [49.2645404871, -123.131048865]
# 3            GW        Grandview-Woodland  [49.2764396102, -123.066728221]
# 4            HS          Hastings-Sunrise   [49.277934053, -123.040269923]
# 5          MARP                   Marpole   [49.2102074666, -123.12838166]
# 6            RP                Riley Park  [49.2447664796, -123.103146806]
# 7          SHAU               Shaughnessy  [49.2456809771, -123.139760167]
# 8           STR                Strathcona  [49.2782195786, -123.088235281]
# 9            WE                  West End  [49.2850111894, -123.135437653]
# 10           DS         Dunbar-Southlands  [49.2379619063, -123.189546803]
# 11         KERR                Kerrisdale  [49.2236554855, -123.159576182]
# 12          KIL                 Killarney  [49.2170216717, -123.037647029]
# 13         KITS                 Kitsilano   [49.2675398494, -123.16329474]
# 14           SC              South Cambie  [49.2455564633, -123.121800916]
# 15           VF       Victoria-Fraserview   [49.220011941, -123.064134718]
# 16           KC  Kensington-Cedar Cottage  [49.2466864472, -123.072884592]
# 17           MP            Mount Pleasant   [49.2630652507, -123.09851312]
# 18          OAK                  Oakridge  [49.2264031973, -123.123024604]
# 19           RC       Renfrew-Collingwood  [49.2473427346, -123.040166465]
# 20          SUN                    Sunset  [49.2187561515, -123.092038001]
# 21          WPG           West Point Grey  [49.2684012111, -123.203467483]
#
#      latitude   longitude
# 0   49.246805 -123.161669
# 1   49.280747 -123.116567
# 2   49.264540 -123.131049
# 3   49.276440 -123.066728
# 4   49.277934 -123.040270
# 5   49.210207 -123.128382
# 6   49.244766 -123.103147
# 7   49.245681 -123.139760
# 8   49.278220 -123.088235
# 9   49.285011 -123.135438
# 10  49.237962 -123.189547
# 11  49.223655 -123.159576
# 12  49.217022 -123.037647
# 13  49.267540 -123.163295
# 14  49.245556 -123.121801
# 15  49.220012 -123.064135
# 16  49.246686 -123.072885
# 17  49.263065 -123.098513
# 18  49.226403 -123.123025
# 19  49.247343 -123.040166
# 20  49.218756 -123.092038
# 21  49.268401 -123.203467

# %% [markdown]
# Drop the geo_pont_2d column, rename the columns and join the geopoints with the neighborhood wiki data to add the descriptions

# %%
flds_geopoints = flds.drop(['fields.geo_point_2d'],axis=1)
flds_geopoints.columns=['Mapid','Name','Latitude','Longitude']
flds_geopoints

neighborhoods = pd.merge(flds_geopoints,df, on='Name')

# %% [markdown]
# Finally print out the Data Frame to make sure we received all 22 neighborhoods

# %%
neighborhoods.head(5)
# Out:
#   Mapid                Name   Latitude   Longitude  \
# 0    AR       Arbutus-Ridge  49.246805 -123.161669
# 1   CBD            Downtown  49.280747 -123.116567
# 2  FAIR            Fairview  49.264540 -123.131049
# 3    GW  Grandview-Woodland  49.276440 -123.066728
# 4    HS    Hastings-Sunrise  49.277934 -123.040270
#
#                                          Description
# 0  Located in the middle of Vancouver's west side...
# 1  The Central business district of Vancouver, co...
# 2  Contains the popular attractions of Granville ...
# 3  Woodland - A mature neighbourhood in east Vanc...
# 4  Sunrise - One of Vancouver's oldest neighbourh...

# %% [markdown]
# # 3. Get the dog population data for each neighborhood

# %% [markdown]
# Prepare to scrape a pdf table by installing tabula-py library

# %%
# !pip install tabula-py
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting tabula-py
#   Downloading tabula_py-2.2.0-py3-none-any.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 10.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from tabula-py) (1.19.2)
# Requirement already satisfied: pandas>=0.25.3 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from tabula-py) (1.0.5)
# Collecting distro
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pandas>=0.25.3->tabula-py) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from pandas>=0.25.3->tabula-py) (2020.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.5.0 tabula-py-2.2.0

# %%
import tabula
import os
java_home = os.environ.get('JAVA_HOME', None)
if not java_home:
    java_path = 'C:/Program Files/Java/jdk1.8.0_11/bin'
    os.environ['JAVA_HOME'] = java_path
else:
    print(java_home)
# Out:
# /opt/ibm/java-x86_64-80

# %%
# %%capture
file='https://vancouver.ca/files/cov/people-parks-dogs-strategy-appendix.pdf'

tables=tabula.read_pdf('https://vancouver.ca/files/cov/people-parks-dogs-strategy-appendix.pdf', pages = "all")
# ignore the errors regarding Java Advanced Imaging as we do not require the images. The capture directive hides the output which contains a long list of these errors

# %% [markdown]
# We are interested in the first table.  Create a new DataFrame containing the relevant columns.

# %%
dogs_table_raw=tables[0]
dogs_table_raw.drop(['Population\r(2011\rCensus)','Off-leash\rArea2\r(ha)','Dog\rdensity\rrelative\rto OLA\rarea3'],inplace=True,axis=1)

# %% [markdown]
# Rename the columns to simplify merging with the other datasets.

# %%
dogs_table=dogs_table_raw
dogs_table.columns=['Name','Area','LicensedDogs','DogDensity']

# %% [markdown]
# Check the output

# %%
dogs_table.head(5)
# Out:
#              Name   Area LicensedDogs  DogDensity
# 0        West End  225.6        1,563         6.9
# 1        Downtown  467.4        3,037         6.5
# 2       Kitsilano  636.3        2,888         4.5
# 3  Mount Pleasant  372.1        1,663         4.5
# 4        Fairview  363.5        1,522         4.2

# %% [markdown]
# # 4. Use Foursquare API to get dog parks near each neighborhood

# %%
# The code was removed by Watson Studio for sharing.

# %%
VERSION = '20210616'
LIMIT = 100

# %%
radius=3000
latitude=neighborhoods['Latitude'][0]
longitude=neighborhoods['Longitude'][0]
print("Lat:  " ,latitude)
print("Long: " ,longitude)
print("Limit: ",LIMIT)
print("query: ",search_query)
print("Radius(m) ",radius)
# Out:
# Lat:   49.2468049108
# Long:  -123.161669238
# Limit:  100
# query:  Dog Park
# Radius(m)  3000

# %%
search_query='Dog Park'
parkurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
parkurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CAUY0NVNOIN1151A2UDU2JI4IFAGVOKOB1W0UFG5PVBDHIQR&client_secret=2B3OHXWDMBGQBMDOWDFJWJW4CDTGRHJ0XVZ2YADOZ1S13OVJ2B3OHXWDMBGQBMDOWDFJWJW4CDTGRHJ0XVZ2YADOZ1S13OVJ&ll=49.2468049108,-123.161669238&oauth_token=XQJX5QJZRCZOA24OINDZWAHBCOTJJWPI3K3UTA0PCVYNU1YA&v=20210616&query=Dog Park&radius=3000&limit=100'

# %% [markdown]
# Send a GET request and check the results

# %%
# inspect the result
results = requests.get(parkurl).json()
venues=results['response']['venues']

#create a DataFrame from the results

# %%
parkvenues= json_normalize(venues)
parkvenues.head(2)
# Out:
# <ipython-input-189-7948d1d2401c>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   parkvenues= json_normalize(venues)
#                          id                      name  \
# 0  4dc60d7d18387d1bd54f2259  Riley Off-leash Dog Park
# 1  51cce800498e94f69b46bc55         Tennyson Dog Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...  v-1626905593    False
# 1  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...  v-1626905593    False
#
#    location.lat  location.lng  \
# 0     49.233811   -123.145569
# 1     49.263107   -123.144244
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat':
#
#            lng                                     labeledLatLngs  distance  \
# 0  -123.145569  [{'label': 'display', 'lat': 49.23381057062191...      1860
# 1  -123.144244  [{'label': 'display', 'lat': 49.26310749421685...      2212
# 2  -123.132565  [{'label': 'display', 'lat': 49.23762412275326...      2349
# 3  -123.192948  [{'label': 'display', 'lat': 49.23392366884049...      2687
# 4  -123.124681  [{'label': 'display', 'lat': 49.26688043290664...      3495
# 5  -123.180234  [{'label': 'display', 'lat': 49.26433201857972...      2371
# 6  -123.152312  [{'label': 'display', 'lat': 49.265822, 'lng':...      2223
# 7  -123.113355  [{'label': 'display', 'lat': 49.24156455524772...      3559
# 8  -123.122123  [{'label': 'display', 'lat': 49.25313168807759...      2958
# 9  -123.158716  [{'label': 'display', 'lat': 49.24948575944954...       367
# 10 -123.171502  [{'label': 'display', 'lat': 49.25767829355637...      1405
# 11 -123.151211  [{'label': 'display', 'lat': 49.24519378222783...       780
# 12 -123.167914  [{'label': 'display', 'lat': 49.24506051970024...       493
# 13 -123.165858  [{'label': 'display', 'lat': 49.25639188402547...      1109
# 14 -123.154980  [{'label': 'display', 'lat': 49.236715, 'lng':...      1223
# 15 -123.173930  [{'label': 'display', 'lat': 49.26921, 'lng': ...      2648
# 16 -123.156167  [{'label': 'display', 'lat': 49.26216797405161...      1756
# 17 -123.179486  [{'label': 'display', 'lat': 49.27192007902685...      3080
# 18 -123.128289  [{'label': 'display', 'lat': 49.23364840460719...      2833
# 19 -123.162899  [{'label': 'display', 'lat': 49.23454763379452...      1367
# 20 -123.122249  [{'label': 'display', 'lat': 49.25177165916665...      2917
# 21 -123.140119  [{'label': 'display', 'lat': 49.262879, 'lng':...      2377
# 22 -123.161831  [{'label': 'display', 'lat': 49.25171175995823...       546
# 23 -123.156180  [{'label': 'display', 'lat': 49.26214801877808...      1753
# 24 -123.176469  [{'label': 'display', 'lat': 49.25242133768195...      1243
# 25 -123.166159  [{'label': 'display', 'lat': 49.272602, 'lng':...      2890
# 26 -123.191471  [{'label': 'display', 'lat': 49.24876483687161...      2176
# 27 -123.174534  [{'label': 'display', 'lat': 49.24512736409405...       953
# 28 -123.115235  [{'label': 'display', 'lat': 49.25454614542726...      3482
# 29 -123.168905  [{'label': 'display', 'lat': 49.27031078280882...      2668
# 30 -123.133127  [{'label': 'display', 'lat': 49.24496008028839...      2084
# 31 -123.176385  [{'label': 'display', 'lat': 49.27145788673623...      2945
# 32 -123.153830  [{'label': 'display', 'lat': 49.23633, 'lng': ...      1297
# 33 -123.112055  [{'label': 'display', 'lat': 49.24202144929457...      3644
# 34 -123.143876  [{'label': 'display', 'lat': 49.25894095852688...      1869
# 35 -123.180282  [{'label': 'display', 'lat': 49.26791628452948...      2711
# 36 -123.142147  [{'label': 'display', 'lat': 49.27581284594059...      3526
# 37 -123.123738  [{'label': 'display', 'lat': 49.26315228221595...      3302
# 38 -123.144463  [{'label': 'display', 'lat': 49.2635423730655,...      2243
# 39 -123.152311  [{'label': 'display', 'lat': 49.25857553009430...      1476
# 40 -123.140381  [{'label': 'display', 'lat': 49.26267670874503...      2348
# 41 -123.153477  [{'label': 'display', 'lat': 49.26170749675559...      1762
# 42 -123.186856  [{'label': 'display', 'lat': 49.2428630815689,...      1882
# 43 -123.165458  [{'label': 'display', 'lat': 49.268317, 'lng':...      2410
# 44 -123.160741  [{'label': 'display', 'lat': 49.26256633750232...      1755
# 45 -123.141860  [{'label': 'display', 'lat': 49.2586210168383,...      1949
# 46 -123.139232  [{'label': 'display', 'lat': 49.25483346521662...      1859
# 47 -123.180973  [{'label': 'display', 'lat': 49.257266, 'lng':...      1823
# 48 -123.127362  [{'label': 'display', 'lat': 49.25184, 'lng': ...      2555
# 49 -123.140217  [{'label': 'display', 'lat': 49.233927, 'lng':...      2118
#
#     cc       city state country  \
# 0   CA  Vancouver    BC  Canada
# 1   CA  Vancouver    BC  Canada
# 2   CA  Vancouver    BC  Canada
# 3   CA  Vancouver    BC  Canada
# 4   CA  Vancouver    BC  Canada
# 5   CA  Vancouver    BC  Canada
# 6   CA  Vancouver    BC  Canada
# 7   CA  Vancouver    BC  Canada
# 8   CA  Vancouver    BC  Canada
# 9   CA        NaN   NaN  Canada
# 10  CA  Vancouver    BC  Canada
# 11  CA  Vancouver    BC  Canada
# 12  CA  Vancouver    BC  Canada
# 13  CA  Vancouver    BC  Canada
# 14  CA  Vancouver    BC  Canada
# 15  CA  Vancouver    BC  Canada
# 16  CA  Vancouver    BC  Canada
# 17  CA  Vancouver    BC  Canada
# 18  CA  Vancouver    BC  Canada
# 19  CA  Vancouver    BC  Canada
# 20  CA  Vancouver    BC  Canada
# 21  CA  Vancouver    BC  Canada
# 22  CA  Vancouver    BC  Canada
# 23  CA  Vancouver    BC  Canada
# 24  CA  Vancouver    BC  Canada
# 25  CA  Vancouver    BC  Canada
# 26  CA        NaN   NaN  Canada
# 27  CA  Vancouver    BC  Canada
# 28  CA  Vancouver    BC  Canada
# 29  CA  Vancouver    BC  Canada
# 30  CA  Vancouver    BC  Canada
# 31  CA  Vancouver    BC  Canada
# 32  CA  Vancouver    BC  Canada
# 33  CA  Vancouver    BC  Canada
# 34  CA        NaN   NaN  Canada
# 35  CA  Vancouver    BC  Canada
# 36  CA  Vancouver    BC  Canada
# 37  CA  Vancouver    BC  Canada
# 38  CA  Vancouver    BC  Canada
# 39  CA  Vancouver    BC  Canada
# 40  CA  Vancouver    BC  Canada
# 41  CA  Vancouver    BC  Canada
# 42  CA  Vancouver    BC  Canada
# 43  CA        NaN   NaN  Canada
# 44  CA        NaN   NaN  Canada
# 45  CA  Vancouver    BC  Canada
# 46  CA  Vancouver    BC  Canada
# 47  CA        NaN   NaN  Canada
# 48  CA  Vancouver    BC  Canada
# 49  CA  Vancouver    BC  Canada
#
#                                      formattedAddress                 address  \
# 0                                      [Vancouver BC]                     NaN
# 1                                      [Vancouver BC]                     NaN
# 2           [899 37th Ave (Oak Street), Vancouver BC]            899 37th Ave
# 3                                      [Vancouver BC]                     NaN
# 4                [999 Charleson St, Vancouver BC V5Z]        999 Charleson St
# 3                        NaN        NaN  4da9d58693a04642f070c1be
# 4                        NaN        V5Z  4aada430f964a5201f6120e3
# 5            Collingwood St.    V6R 2B3  4ded63e2c65bf34fc6d4933e
# 6              at Arbutus St        NaN  4bae9b34f964a520edc53be3
# 7                        NaN        NaN  4bdf6cddffdec9287a09eca1
# 8                  Willow St        NaN  4aaae9fff964a5200b5820e3
# 9                        NaN        NaN  50f48eb2e4b0e3ab976fd593
# 10                       NaN        NaN  4bd32ee241b9ef3b1279ffe5
# 11              at Valley Dr        NaN  4bd88c2851170f47af9933e4
# 12                       NaN        NaN  4e59ea5c52b1b78b81a3db04
# 13                       NaN    V6L 1B4  5127b04fe0e2075351eac908
# 14                       NaN        NaN  51b8e1e2498e3afe5e2bead9
# 15                   3rd Ave        NaN  4c01e5caf8492d7f96a95ffa
# 16  btwn 10th Ave & 12th Ave    V6K 4K9  4ab01a02f964a520e66520e3
# 17              Waterloo St.        NaN  4b81b6b4f964a52075b930e3
# 18                Montgomery        NaN  4c64ab6de0c4be9ae7518658
# 19            at W. 41st Ave        NaN  4be9e2786295c9b6cccb8508
# 20                       NaN    V5Z 1Z8  4d3c7c3c3ec9a35d9d0e4981
# 21                       NaN        NaN  4ff8b4dce4b0903668e9a6da
# 22          West 23rd Avenue        NaN  4ab67ce3f964a520627720e3
# 23                   Vine St        NaN  4cd1e2c97b685481529ac9f8
# 24                       NaN        NaN  4df040e245ddbf3897d17127
# 25                       NaN        NaN  4f712943e4b0a89fa42f488c
# 26                       NaN        NaN  4b92f115f964a520df2834e3
# 27                 30th Ave.        NaN  4b2d241df964a5205acf24e3
# 28                       NaN        NaN  4aa9879af964a5201b5420e3
# 29                       NaN        NaN  4e1bb9f662e11cdc743c5277
# 30                       NaN        NaN  51b10fee498e34ecba9b2e44
# 31             Trutch Street        NaN  4b465687f964a520f81d26e3
# 32                       NaN    V6M 3V2  5bc1277b61f070002cd73c80
# 33             Cambie Street    V6G 3E7  4ad15d40f964a5203ade20e3
# 34                       NaN        NaN  4c7e9351e4b06dcb2e8444d7
# 35                  Waterloo        NaN  4ab6dba2f964a520547920e3
# 36                  Chestnut        NaN  4aad7ad6f964a520836020e3
# 37                       NaN    V5Z 1J8  4bbd263ea0a0c9b68c561b0f
# 38                       NaN        NaN  4ab7f4d8f964a520987b20e3
# 39                       NaN        NaN  4c8011ccdc018cfa0132b96c
# 40                     W11th        NaN  4e13705522713f7d7be2dcd4
# 41       btwn Vine & Arbutus    V6G 1Z4  4e5a93b81fc7864a236a8792
# 42                       NaN        NaN  4da9e2c40cb6a89c62612309
# 43                       NaN        NaN  4bf6e5c15ec320a1e1fb85d3
# 44                       NaN        NaN  4d10f7cac3dc3704c7ca3c74
# 45                       Fir        NaN  4ae0c44df964a520488221e3
# 46           at Granville St        NaN  4ea28479dab472526ff639e7
# 47                       NaN        NaN  50492dfde4b0fbb31242aefb
# 48                    E 22nd        NaN  4dc56e3be4cd169dc64bfb3b
# 49                       NaN        NaN  506e39e6e4b030d2b851343d

# %%
#get those where either the name matches 'Dog Park' or the category matches 'Dog Run', and add them together into a dataframe
dfc1=dataframe_filtered[dataframe_filtered['name'].str.contains('Dog Park')]
dfc2=dataframe_filtered[dataframe_filtered['categories'].str.contains('Dog Run', na=False)]
dogparks=pd.concat([dfc1, dfc2])

#remove duplicates where it matched both
dogparks=dogparks.drop_duplicates(subset=['name'])

dogparks.shape
# Out:
# (5, 15)

# %%
dogparks
# Out:
#                        name categories        lat         lng  \
# 0  Riley Off-leash Dog Park    Dog Run  49.233811 -123.145569
# 1         Tennyson Dog Park    Dog Run  49.263107 -123.144244
# 2    Oak Meadows - Dog Park    Dog Run  49.237624 -123.132565
# 3            Crown Dog Park       None  49.233924 -123.192948
# 5       Dogcity Dog Daycare    Dog Run  49.264332 -123.180234
#
#                                       labeledLatLngs  distance  cc       city  \
# 0  [{'label': 'display', 'lat': 49.23381057062191...      1860  CA  Vancouver
# 1  [{'label': 'display', 'lat': 49.26310749421685...      2212  CA  Vancouver
# 2  [{'label': 'display', 'lat': 49.23762412275326...      2349  CA  Vancouver
# 3  [{'label': 'display', 'lat': 49.23392366884049...      2687  CA  Vancouver
# 5  [{'label': 'display', 'lat': 49.26433201857972...      2371  CA  Vancouver
#
#   state country                                   formattedAddress  \
# 0    BC  Canada                                     [Vancouver BC]
# 1    BC  Canada                                     [Vancouver BC]
# 2    BC  Canada          [899 37th Ave (Oak Street), Vancouver BC]
# 3    BC  Canada                                     [Vancouver BC]
# 5    BC  Canada  [3458 West Broadway (Collingwood St.), Vancouv...
#
#               address      crossStreet postalCode                        id
# 0                 NaN              NaN        NaN  4dc60d7d18387d1bd54f2259
# 1                 NaN              NaN        NaN  51cce800498e94f69b46bc55
# 2        899 37th Ave       Oak Street        NaN  5068f79ae4b0bb2afa9aba56
# 3                 NaN              NaN        NaN  4da9d58693a04642f070c1be
# 5  3458 West Broadway  Collingwood St.    V6R 2B3  4ded63e2c65bf34fc6d4933e

# %% [markdown]
# # 5. Use Foursquare again to identify pubs and bars near each venue

# %%
search_query='pub'
pubsurl = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
pubsurl
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=CAUY0NVNOIN1151A2UDU2JI4IFAGVOKOB1W0UFG5PVBDHIQR&client_secret=2B3OHXWDMBGQBMDOWDFJWJW4CDTGRHJ0XVZ2YADOZ1S13OVJ2B3OHXWDMBGQBMDOWDFJWJW4CDTGRHJ0XVZ2YADOZ1S13OVJ&ll=49.2468049108,-123.161669238&oauth_token=XQJX5QJZRCZOA24OINDZWAHBCOTJJWPI3K3UTA0PCVYNU1YA&v=20210616&query=pub&radius=3000&limit=100'

# %% [markdown]
# Send the GET request

# %%
# inspect the result
pubresults = requests.get(pubsurl).json()
pubvenues=pubresults['response']['venues']

#create a DataFrame from the results

# %% [markdown]
# ### Data Wrangling

# %%
pubs_raw= json_normalize(pubvenues)
pubs_raw.head(2)
# Out:
# <ipython-input-298-23a6f4116976>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   pubs_raw= json_normalize(pubvenues)
#                          id                       name  \
# 0  4aabfb4af964a520625b20e3       Darby's Public House
# 1  4da64682a86ecc5168cc7385  The Manchester Pub Eatery
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1626912401    False
# 1  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1626912401    False
#
#      location.address location.crossStreet  location.lat  location.lng  \
# 0   2001 MacDonald St         at W 4th Ave     49.268337   -123.168383
# 1  1941 West Broadway          Cypress St.     49.263855   -123.149194
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 49.26833731277357...               2446
# 1  [{'label': 'display', 'lat': 49.26385482819924...               2103
#
#   location.postalCode location.cc location.city location.state  \
# 0             V6K 3Y2          CA     Vancouver             BC
# 1             V6J 1Z3          CA     Vancouver             BC
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [2001 MacDonald St (at W 4th Ave), Vancouver B...
# 1           Canada  [1941 West Broadway (Cypress St.), Vancouver B...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN

# %%
filtered_columns = ['name', 'categories'] + [col for col in pubs_raw.columns if col.startswith('location.')] + ['id']
pubs_filtered = pubs_raw.loc[:, filtered_columns]
pubs_filtered
# Out:
#                                      name  \
# 0                    Darby's Public House
# 1               The Manchester Pub Eatery
# 2                      The Kings Head Pub
# 3                             Darby's Pub
# 4                   Buru-Bin Japanese Pub
# 5               The Cove Neighborhood Pub
# 6                   Kitsilano Public Pool
# 7                         Local Kitsilano
# 8          Granville Island Public Market
# 9   Vancouver Public Library - Kerrisdale
# 10   Vancouver Public Library - Kitsilano
# 11               Granville Island Brewing
# 12                     Bridges Restaurant
# 13                         Public Storage
# 14    Vancouver Public Library - Firehall
# 15       Law Office Notary Public Gary Lo
# 16      Vancouver Public Library - Dunbar
# 17                    Dunbar Public House
# 18              Kits Beach Public Parking
# 19     radovic & associates Notary Public
# 20  Deprez and Associates Notaries Public
# 21               A.J. Kwong Notary Public
# 22               Vancouver Public Library
# 23                The Bimini Public House
# 24            Rajio Japanese Public House
#
#                                            categories  \
# 0   [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 1   [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 2   [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 3                                                  []
# 4   [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 5   [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 6   [{'id': '4bf58dd8d48988d15e941735', 'name': 'P...
# 7   [{'id': '4bf58dd8d48988d157941735', 'name': 'N...
# 8   [{'id': '50be8ee891d4fa8dcc7199a7', 'name': 'M...
# 9   [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...
# 10  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...
# 11  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...
# 12  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...
# 13  [{'id': '4f04b1572fb6e1c99f3db0bf', 'name': 'S...
# 14  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...
# 15  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...
# 16  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...
# 17  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 18  [{'id': '4d954b16a243a5684b65b473', 'name': 'R...
# 19  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...
# 20  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...
# 21  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...
# 22  [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...
# 23  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 24  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
#
#             location.address       location.crossStreet  location.lat  \
# 0          2001 MacDonald St               at W 4th Ave     49.268337
# 1         1941 West Broadway                Cypress St.     49.263855
# 2                1618 Yew St  btwn York Ave & 1st Ave W     49.271264
# 3      2001 Macdonald Street                        NaN     49.268367
# 4                3089 Oak St                        NaN     49.261951
# 5            3681 W 4th Ave.                at Alma St.     49.268657
# 6          2305 Cornwall Ave                       Vine     49.273215
# 7          2210 Cornwall Ave                        NaN     49.272481
# 8          1661 Duranleau St             at Johnston St     49.272488
# 9           2112 W 42nd Ave.              at West Blvd.     49.233276
# 10        2425 MacDonald St.                at Broadway     49.264802
# 11    1441 Cartwright Street           at Old Bridge St     49.270563
# 12         1696 Duranleau St                        NaN     49.272910
# 13            1698 W 3rd Ave                        NaN     49.268754
# 14          1455 W 10th Ave.            at Granville St     49.262730
# 15       5728 East Boulevard           West 41st Avenue     49.234386
# 16           4515 Dunbar St.               at 29th Ave.     49.245957
# 17            4497 Dunbar St                at 29th Ave     49.246294
# 18                       NaN                        NaN     49.272806
# 19                       NaN                        NaN     49.262344
# 20          2515 Alma Street              West Broadway     49.263828
# 21  316-1529 West 6th Avenue           Granville Street     49.263760
# 22           Oakridge Centre               at Cambie St     49.231187
# 23            2010 W 4th Ave                at Maple St     49.267957
# 24           3763 W 10th Ave       btwn Alma & Highbury     49.263516
#
#     location.lng                            location.labeledLatLngs  \
# 0    -123.168383  [{'label': 'display', 'lat': 49.26833731277357...
# 1    -123.149194  [{'label': 'display', 'lat': 49.26385482819924...
# 2    -123.154943  [{'label': 'display', 'lat': 49.27126405934131...
# 3    -123.168335  [{'label': 'display', 'lat': 49.2683669, 'lng'...
# 4    -123.127045  [{'label': 'display', 'lat': 49.26195136007178...
# 5    -123.185277  [{'label': 'display', 'lat': 49.26865659044266...
# 6    -123.157413  [{'label': 'display', 'lat': 49.27321534899229...
# 7    -123.155240  [{'label': 'display', 'lat': 49.27248135691792...
# 8    -123.135281  [{'label': 'display', 'lat': 49.27248788116003...
# 9    -123.156252  [{'label': 'display', 'lat': 49.23327575266476...
# 10   -123.168726  [{'label': 'display', 'lat': 49.26480225940434...
# 11   -123.135667  [{'label': 'display', 'lat': 49.27056306074294...
# 12   -123.136511  [{'label': 'display', 'lat': 49.27291014679782...
# 13   -123.143006  [{'label': 'display', 'lat': 49.26875429861958...
# 14   -123.137494  [{'label': 'display', 'lat': 49.26273001008710...
# 15   -123.155110  [{'label': 'display', 'lat': 49.23438633327713...
# 16   -123.185400  [{'label': 'display', 'lat': 49.24595713730117...
# 17   -123.185486  [{'label': 'display', 'lat': 49.24629391104717...
# 18   -123.153934  [{'label': 'display', 'lat': 49.27280596340439...
# 19   -123.137794  [{'label': 'display', 'lat': 49.26234436035156...
# 20   -123.185845  [{'label': 'display', 'lat': 49.26382784319165...
# 21   -123.138980  [{'label': 'display', 'lat': 49.26376, 'lng': ...
# 22   -123.118924  [{'label': 'display', 'lat': 49.23118703126005...
# 23   -123.150845  [{'label': 'display', 'lat': 49.26795664849493...
# 24   -123.187086  [{'label': 'display', 'lat': 49.26351643194259...
#
#     location.distance location.postalCode location.cc location.city  \
# 0                2446             V6K 3Y2          CA     Vancouver
# 1                2103             V6J 1Z3          CA     Vancouver
# 2                2766             V6K 3E7          CA     Vancouver
# 3                2448             V6K 3Y2          CA     Vancouver
# 4                3028             V6H 2K8          CA     Vancouver
# 5                2976             V6R 1P2          CA     Vancouver
# 6                2956                 NaN          CA     Vancouver
# 7                2896             V6K 1B5          CA     Vancouver
# 8                3442             V6H 3S4          CA     Vancouver
# 9                1556             V6M 2B6          CA     Vancouver
# 10               2068             V6K 3Y9          CA     Vancouver
# 11               3250             V6H 3Y5          CA     Vancouver
# 12               3432             V6H 3S4          CA     Vancouver
# 13               2794             V6J 1K3          CA     Vancouver
# 14               2495             V6H 1J8          CA     Vancouver
# 15               1462                 NaN          CA     Vancouver
# 16               1727             V6S 2G7          CA     Vancouver
# 17               1731             V6S 2E1          CA     Vancouver
# 18               2948                 NaN          CA     Vancouver
# 19               2449                 NaN          CA     Vancouver
# 20               2583                 NaN          CA     Vancouver
# 21               2505             V6J 1R1          CA     Vancouver
# 22               3560             V5Z 3M5          CA     Vancouver
# 23               2482             V6J 1M9          CA     Vancouver
# 24               2621                 NaN          CA     Vancouver
#
#    location.state location.country  \
# 0              BC           Canada
# 1              BC           Canada
# 2              BC           Canada
# 3              BC           Canada
# 4              BC           Canada
# 5              BC           Canada
# 6              BC           Canada
# 7              BC           Canada
# 8              BC           Canada
# 9              BC           Canada
# 10             BC           Canada
# 11             BC           Canada
# 12             BC           Canada
# 13             BC           Canada
# 14             BC           Canada
# 15             BC           Canada
# 16             BC           Canada
# 17             BC           Canada
# 18             BC           Canada
# 19             BC           Canada
# 20             BC           Canada
# 21             BC           Canada
# 22             BC           Canada
# 23             BC           Canada
# 24             BC           Canada
#
#                             location.formattedAddress location.neighborhood  \
# 0   [2001 MacDonald St (at W 4th Ave), Vancouver B...                   NaN
# 1   [1941 West Broadway (Cypress St.), Vancouver B...                   NaN
# 2   [1618 Yew St (btwn York Ave & 1st Ave W), Vanc...                   NaN
# 3       [2001 Macdonald Street, Vancouver BC V6K 3Y2]                   NaN
# 4                 [3089 Oak St, Vancouver BC V6H 2K8]                   NaN
# 5   [3681 W 4th Ave. (at Alma St.), Vancouver BC V...                   NaN
# 6            [2305 Cornwall Ave (Vine), Vancouver BC]                   NaN
# 7           [2210 Cornwall Ave, Vancouver BC V6K 1B5]                   NaN
# 8   [1661 Duranleau St (at Johnston St), Vancouver...                   NaN
# 9   [2112 W 42nd Ave. (at West Blvd.), Vancouver B...                   NaN
# 10  [2425 MacDonald St. (at Broadway), Vancouver B...                   NaN
# 11  [1441 Cartwright Street (at Old Bridge St), Va...                   NaN
# 12          [1696 Duranleau St, Vancouver BC V6H 3S4]                   NaN
# 13             [1698 W 3rd Ave, Vancouver BC V6J 1K3]                   NaN
# 14  [1455 W 10th Ave. (at Granville St), Vancouver...                   NaN
# 15  [5728 East Boulevard (West 41st Avenue), Vanco...                   NaN
# 16  [4515 Dunbar St. (at 29th Ave.), Vancouver BC ...                   NaN
# 17  [4497 Dunbar St (at 29th Ave), Vancouver BC V6...     Dunbar-Southlands
# 18                                     [Vancouver BC]                   NaN
# 19                                     [Vancouver BC]                   NaN
# 20   [2515 Alma Street (West Broadway), Vancouver BC]                   NaN
# 21  [316-1529 West 6th Avenue (Granville Street), ...       South Granville
# 22  [Oakridge Centre (at Cambie St), Vancouver BC ...                   NaN
# 23  [2010 W 4th Ave (at Maple St), Vancouver BC V6...                   NaN
# 24  [3763 W 10th Ave (btwn Alma & Highbury), Vanco...                   NaN
#
#                           id
# 0   4aabfb4af964a520625b20e3
# 1   4da64682a86ecc5168cc7385
# 2   50c2589fe4b0489424ed0c46
# 3   546d2cc9498e44fc86358f4e
# 4   51a6779e498e83f4ce88c0a2
# 5   4ce34268ef2db60c08c1bf5b
# 6   4aaad0fff964a5208c5720e3
# 7   4b10463af964a520ce6c23e3
# 8   4aa7f646f964a5203d4e20e3
# 9   4b662e96f964a520e1172be3
# 10  4afa3c9cf964a520751722e3
# 11  4aa74c7bf964a520a34c20e3
# 12  4aa7fa99f964a520724e20e3
# 13  532dbad9498eac97fae999d5
# 14  4ab52398f964a520b77220e3
# 15  57212355498eaeb1b88a7c33
# 16  4b034d38f964a5206d4e22e3
# 17  4b1dd020f964a520901524e3
# 18  4becbfc06b88c9b6e1788762
# 19  54271304498e786c48167140
# 20  4d0bdbf0adf0a143a021857c
# 21  55edd380498e895907ff9129
# 22  4abd5b3ff964a520e48920e3
# 23  4b722eb3f964a520f1722de3
# 24  50a9cf12e4b05977cf5e16ab

# %%
# filter the category for each row
#pubs_filtered['categories'] = pubs_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
#pubs_filtered.columns = [column.split('.')[-1] for column in pubs_filtered.columns]
#pubs_filtered

# %%
pubs_filtered.shape
# Out:
# (25, 16)

# %%
pubs_filtered.head(5)
# Out:
#                         name           categories       location.address  \
# 0       Darby's Public House                  Pub      2001 MacDonald St
# 1  The Manchester Pub Eatery                  Pub     1941 West Broadway
# 2         The Kings Head Pub                  Pub            1618 Yew St
# 3                Darby's Pub                 None  2001 Macdonald Street
# 4      Buru-Bin Japanese Pub  Japanese Restaurant            3089 Oak St
#
#         location.crossStreet  location.lat  location.lng  \
# 0               at W 4th Ave     49.268337   -123.168383
# 1                Cypress St.     49.263855   -123.149194
# 2  btwn York Ave & 1st Ave W     49.271264   -123.154943
# 3                        NaN     49.268367   -123.168335
# 4                        NaN     49.261951   -123.127045
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 49.26833731277357...               2446
# 1  [{'label': 'display', 'lat': 49.26385482819924...               2103
# 2  [{'label': 'display', 'lat': 49.27126405934131...               2766
# 3  [{'label': 'display', 'lat': 49.2683669, 'lng'...               2448
# 4  [{'label': 'display', 'lat': 49.26195136007178...               3028
#
#   location.postalCode location.cc location.city location.state  \
# 0             V6K 3Y2          CA     Vancouver             BC
# 1             V6J 1Z3          CA     Vancouver             BC
# 2             V6K 3E7          CA     Vancouver             BC
# 3             V6K 3Y2          CA     Vancouver             BC
# 4             V6H 2K8          CA     Vancouver             BC
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [2001 MacDonald St (at W 4th Ave), Vancouver B...
# 1           Canada  [1941 West Broadway (Cypress St.), Vancouver B...
# 2           Canada  [1618 Yew St (btwn York Ave & 1st Ave W), Vanc...
# 3           Canada      [2001 Macdonald Street, Vancouver BC V6K 3Y2]
# 4           Canada                [3089 Oak St, Vancouver BC V6H 2K8]
#
#   location.neighborhood                        id
# 0                   NaN  4aabfb4af964a520625b20e3
# 1                   NaN  4da64682a86ecc5168cc7385
# 2                   NaN  50c2589fe4b0489424ed0c46
# 3                   NaN  546d2cc9498e44fc86358f4e
# 4                   NaN  51a6779e498e83f4ce88c0a2
